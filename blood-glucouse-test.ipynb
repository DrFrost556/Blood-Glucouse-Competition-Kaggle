# %%
# Library Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import gc
from sklearn.model_selection import RepeatedStratifiedKFold, StratifiedKFold, train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.ensemble import VotingClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
import optuna
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from scipy.sparse import csr_matrix, hstack
from sklearn.metrics import mean_squared_error
from catboost import CatBoostClassifier, Pool
from sklearn.model_selection import KFold  # Assuming no stratification needed for regression
import gc
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
import lightgbm as lgb
from lightgbm import log_evaluation, early_stopping
import re
import polars as pl
from catboost import CatBoostRegressor, Pool
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import mean_squared_error

pd.set_option('future.no_silent_downcasting', True)

# %%
train_data=pl.read_csv("/kaggle/input/brist1d/train.csv")
train_data=train_data.to_pandas()
test_data=pl.read_csv("/kaggle/input/brist1d/test.csv")
test_data=test_data.to_pandas()
print(len(train_data),len(test_data))
train_data.head()
# Out:
# 177024 3644
#       id p_num      time bg-5:55  bg-5:50  bg-5:45 bg-5:40  bg-5:35  bg-5:30  \
# 0  p01_0   p01  06:10:00    None      NaN      9.6    None      NaN      9.7
# 1  p01_1   p01  06:25:00    None      NaN      9.7    None      NaN      9.2
# 2  p01_2   p01  06:40:00    None      NaN      9.2    None      NaN      8.7
# 3  p01_3   p01  06:55:00    None      NaN      8.7    None      NaN      8.4
# 4  p01_4   p01  07:10:00    None      NaN      8.4    None      NaN      8.1
#
#   bg-5:25  ...  activity-0:40  activity-0:35 activity-0:30  activity-0:25  \
# 0    None  ...           None           None          None           None
# 1    None  ...           None           None          None           None
# 2    None  ...           None           None          None           None
# 3    None  ...           None           None          None           None
# 4    None  ...           None           None          None           None
#
#    activity-0:20 activity-0:15  activity-0:10  activity-0:05 activity-0:00  \
# 0           None          None           None           None          None
# 1           None          None           None           None          None
# 2           None          None           None           None          None
# 3           None          None           None           None          None
# 4           None          None           None           None          None
#
#    bg+1:00
# 0     13.4
# 1     12.8
# 2     15.5
# 3     14.8
# 4     12.7
#
# [5 rows x 508 columns]

# %%
test_id = test_data["id"]

# %%
#six float features
feats=['bg','insulin','hr','steps','cals','activity']
ts=['-5:55', '-5:50', '-5:45', '-5:40', '-5:35', '-5:30', '-5:25', '-5:20', 
    '-5:15', '-5:10', '-5:05', '-5:00', '-4:55', '-4:50', '-4:45', '-4:40', 
    '-4:35', '-4:30', '-4:25', '-4:20', '-4:15', '-4:10', '-4:05', '-4:00', 
    '-3:55', '-3:50', '-3:45', '-3:40', '-3:35', '-3:30', '-3:25', '-3:20', 
    '-3:15', '-3:10', '-3:05', '-3:00', '-2:55', '-2:50', '-2:45', '-2:40', 
    '-2:35', '-2:30', '-2:25', '-2:20', '-2:15', '-2:10', '-2:05', '-2:00', 
    '-1:55', '-1:50', '-1:45', '-1:40', '-1:35', '-1:30', '-1:25', '-1:20', 
    '-1:15', '-1:10', '-1:05', '-1:00', '-0:55', '-0:50', '-0:45', '-0:40', 
    '-0:35', '-0:30', '-0:25', '-0:20', '-0:15', '-0:10', '-0:05', '-0:00']
def get_more_data(df,timestep,mode='train'):#mode is train or test
    full_data=[]
    #12step is 1 hour.
    for start in range(0,len(ts)-timestep-12):
        end=start+timestep
        target=end+12
        #[start:end] target
        hours_data=df[['p_num']+[f+ts[i]  for i in range(start,end) for f in feats]+['bg'+ts[target]]]
        hours_data.columns=['p_num']+[f+str(i-start)  for i in range(start,end)for f in feats]+['bg+1:00']
        hours_data=hours_data[~hours_data['bg+1:00'].isna()]
        full_data.append(hours_data)
    if mode=='test':
        hours_data=df[['p_num']+[f+ts[i]  for i in range(len(ts)-timestep,len(ts)) for f in feats]]
        hours_data.columns=['p_num']+[f+str(i-len(ts)+timestep)  for i in range(len(ts)-timestep,len(ts))for f in feats]
        full_data.append(hours_data)
    full_data=pd.concat(full_data).drop_duplicates()
    return full_data

# %%
def FE(df, mode='train', timestep=36):
    print("< drop useless columns >")
    df.drop([c for c in df.columns if 'carbs' in c] + ['id'], axis=1, inplace=True)

    print("< fillna >")
    bgs = [c for c in list(df.columns) if (c != 'bg+1:00') and ('bg' in c)]
    df[bgs] = df[bgs].ffill(axis=1)
    df[bgs] = df[bgs].bfill(axis=1)

    print("< log1p transform >")
    step_cols = [c for c in list(df.columns) if 'step' in c]
    df[step_cols] = df[step_cols].fillna(50).astype(np.float32)
    df[step_cols] = np.log1p(df[step_cols])
    
    print("< fix bug >")
    float_cols = [c for c in df.columns for f in feats[:-1] if f in c]
    df[float_cols] = df[float_cols].astype(np.float32)

    print("< get more data >")
    df = get_more_data(df, timestep=timestep, mode=mode)

    df['p_num_int'] = df['p_num'].apply(lambda x: int(x[1:])).astype(np.int8)

    print("< fill missing feature values >")
    float_cols = [col + str(ts) for ts in range(timestep) for col in ['bg', 'insulin', 'hr', 'steps', 'cals']]
    df[float_cols] = df[float_cols].fillna(-1)

    print("< activity feature >")
    activity_cols = [c for c in list(df.columns) if 'activity' in c]
    activity_feats = df[activity_cols].replace('None', '').fillna('')
    df['activity_present'] = activity_feats.apply(lambda row: any(row), axis=1).astype(int)
    df.drop(activity_cols, axis=1, inplace=True)

    print("< Z-score feature >")
    cols = ['bg', 'insulin', 'steps', 'hr', 'cals']

    # Create columns for timestep suffix only once
    suffix = f"{timestep - 1}"
    cols_with_suffix = [f"{col}{suffix}" for col in cols]

    # Group by `p_num` and calculate mean and std for each feature at the given timestep
    grouped_stats = df.groupby('p_num')[cols_with_suffix].agg(['mean', 'std']).reset_index()
    grouped_stats.columns = ['p_num'] + [f"{stat}_pnum_{col}" for col in cols_with_suffix for stat in ['mean', 'std']]

    # Join the mean and std columns back to the original DataFrame on `p_num`
    df = df.merge(grouped_stats, on='p_num', how='left')

    # Calculate z-scores for each column using the joined mean and std
    z_score_features = {}
    for col in cols:
        mean_col = f'mean_pnum_{col}{suffix}'
        std_col = f'std_pnum_{col}{suffix}'
        z_score_features[f'norm_pnum_{col}{suffix}'] = (df[f'{col}{suffix}'] - df[mean_col]) / df[std_col]

    # Convert z-score calculations to DataFrame and join all at once to avoid fragmentation
    z_score_df = pd.DataFrame(z_score_features)
    df = pd.concat([df, z_score_df], axis=1)

    print("< cross feature >")
    cross = ['bg', 'insulin', 'steps', 'hr', 'cals']
    for i in range(len(cross)):
        for j in range(i + 1, len(cross)):
            for k in [1]:
                df[f"{cross[i]}{timestep - k}_{cross[j]}{timestep - k}"] = df[f"{cross[i]}{timestep - k}"] * df[f"{cross[j]}{timestep - k}"]

    return df

# %%
train = FE(train_data, mode='train')
test = FE(test_data, mode='test')
total = pd.concat((train, test))
test = total[total['bg+1:00'].isna()]
train = total[~total['bg+1:00'].isna()]
test.drop(["bg+1:00"], axis=1, inplace=True)

print(len(train), len(test), len(total))
train.head()
# Out:
# < drop useless columns >
# < fillna >
# < log1p transform >
# < fix bug >
# < get more data >
# < fill missing feature values >
# < activity feature >
# /tmp/ipykernel_23/581369802.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['activity_present'] = activity_feats.apply(lambda row: any(row), axis=1).astype(int)
# < Z-score feature >
# < cross feature >
# < drop useless columns >
# < fillna >
# < log1p transform >
# < fix bug >
# < get more data >
# /tmp/ipykernel_23/581369802.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['p_num_int'] = df['p_num'].apply(lambda x: int(x[1:])).astype(np.int8)
# < fill missing feature values >
# < activity feature >
# /tmp/ipykernel_23/581369802.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['activity_present'] = activity_feats.apply(lambda row: any(row), axis=1).astype(int)
# < Z-score feature >
# < cross feature >
# 356075 3644 359719
# /tmp/ipykernel_23/2553637795.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.drop(["bg+1:00"], axis=1, inplace=True)
#   p_num  bg0  insulin0  hr0    steps0  cals0  bg1  insulin1  hr1    steps1  \
# 0   p01  9.6    0.0083 -1.0  3.931826   -1.0  9.6    0.0083 -1.0  3.931826
# 1   p01  9.7    0.0083 -1.0  3.931826   -1.0  9.7    0.0083 -1.0  3.931826
# 2   p01  9.2    0.0083 -1.0  3.931826   -1.0  9.2    0.0083 -1.0  3.931826
# 3   p01  8.7    0.0083 -1.0  3.931826   -1.0  8.7    0.0083 -1.0  3.931826
# 4   p01  8.4    0.0083 -1.0  3.931826   -1.0  8.4    0.0083 -1.0  3.931826
#
#    ...  bg35_insulin35  bg35_steps35  bg35_hr35  bg35_cals35  \
# 0  ...         0.11537     54.652374 -13.900000   -13.900000
# 1  ...         0.11786     55.831924 -14.200000   -14.200000
# 2  ...         0.11786     55.831924 -14.200000   -14.200000
# 3  ...         0.12782     60.550114 -15.400000   -15.400000
# 4  ...         1.00276     67.627403 -17.200001   -17.200001
#
#    insulin35_steps35  insulin35_hr35  insulin35_cals35  steps35_hr35  \
# 0           0.032634         -0.0083           -0.0083     -3.931826
# 1           0.032634         -0.0083           -0.0083     -3.931826
# 2           0.032634         -0.0083           -0.0083     -3.931826
# 3           0.032634         -0.0083           -0.0083     -3.931826
# 4           0.229225         -0.0583           -0.0583     -3.931826
#
#    steps35_cals35  hr35_cals35
# 0       -3.931826          1.0
# 1       -3.931826          1.0
# 2       -3.931826          1.0
# 3       -3.931826          1.0
# 4       -3.931826          1.0
#
# [5 rows x 209 columns]

# %%
def cat_process(data, timestep=36):
    df = data.copy()
    cols = ['bg', 'insulin', 'steps', 'hr', 'cals']
    suffix = f"{timestep - 1}"

    for col in cols:
        df[f'mean_pnum_{col}{suffix}'] = df[f'mean_pnum_{col}{suffix}'].astype('string').astype('category')
        df[f'std_pnum_{col}{suffix}'] = df[f'std_pnum_{col}{suffix}'].astype('string').astype('category')
        df[f'norm_pnum_{col}{suffix}'] = df[f'norm_pnum_{col}{suffix}'].astype('string').astype('category')
        
    df['p_num'] = df['p_num'].astype('string').astype('category')
    df['activity_present'] = df['activity_present'].astype('string').astype('category')
    
    return df

# %%
train_cat = cat_process(train)
test_cat = cat_process(test)

# %%
train_cat.drop(["p_num_int"], axis=1, inplace=True)
test_cat.drop(["p_num_int"], axis=1, inplace=True)

train.drop(["p_num"], axis=1, inplace=True)
test.drop(["p_num"], axis=1, inplace=True)
# Out:
# /tmp/ipykernel_23/1964283331.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.drop(["p_num"], axis=1, inplace=True)
# /tmp/ipykernel_23/1964283331.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.drop(["p_num"], axis=1, inplace=True)

# %%
def cross_validate_cat(params, X, y, test_data, n_splits=2, n_bags=1, random_state=42):
    oof_preds = np.zeros(len(X))
    test_preds = np.zeros(len(test_data))
    scores = []
    kfold = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    
    cat_features = X.select_dtypes(include=['category', 'object']).columns.tolist()
    
    for fold, (train_index, valid_index) in enumerate(kfold.split(X, y)):
        for i in range(n_bags):
            
            # Split train and validation data
            X_train = X.iloc[train_index].copy()
            y_train = y.iloc[train_index]
            X_val = X.iloc[valid_index].copy()
            y_val = y.iloc[valid_index]
            
            # Convert categorical features to strings
            for cat_col in cat_features:
                X_train[cat_col] = X_train[cat_col].astype(str)
                X_val[cat_col] = X_val[cat_col].astype(str)
                test_data[cat_col] = test_data[cat_col].astype(str)
                
            # Create CatBoost Pools for train, validation, and test data
            train_pool = Pool(data=X_train, label=y_train, cat_features=cat_features)
            val_pool = Pool(data=X_val, label=y_val, cat_features=cat_features)
            test_pool = Pool(data=test_data, cat_features=cat_features)

            model = CatBoostRegressor(**params, eval_metric='RMSE', random_seed=42, early_stopping_rounds=100, verbose=100, task_type='GPU')
            # Fit model
            model.fit(train_pool, eval_set=val_pool)
            
            y_pred = model.predict(val_pool)
            rmse = np.sqrt(mean_squared_error(y_val, y_pred))
            print(f"# Fold {fold}, bag {i}: RMSE={rmse:.5f}")
            scores.append(rmse)
            
            oof_preds[valid_index] += y_pred / n_bags
            test_preds += model.predict(test_pool) / kfold.get_n_splits() / n_bags
            
            del model
            gc.collect()
            
        print(f"#RMSE mean: {np.mean(scores):.7f} (+- {np.std(scores):.7f})")

    return oof_preds, test_preds

# %%
def cross_validate(params, model_type, X, y, test_data, n_splits=2, n_bags = 1, random_state=42):
    oof_preds = np.zeros(len(X))
    test_preds = np.zeros(len(test_data))
    scores = []
    kfold = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    
    for fold, (train_index, valid_index) in enumerate(kfold.split(X,y)):
        for i in range(0,n_bags):
            X_train = X.iloc[train_index]
            y_train = y.iloc[train_index]
            X_val = X.iloc[valid_index]
            y_val = y.iloc[valid_index]
            
            if model_type == 'lgb':
                model = LGBMRegressor(**params)
                model.fit(X_train, y_train, eval_set=[(X_val, y_val)],callbacks = callbacks)
            elif model_type == 'xgb':
                model = XGBRegressor(**params, early_stopping_rounds=100, n_jobs=4, random_state=42, max_bin=100000, device="cuda")
                model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose = 300)
            
            y_pred = model.predict(X_val)
            rmse = np.sqrt(mean_squared_error(y_val, y_pred))
            print(f"# Fold {fold}, bag {i}: RMSE={rmse:.5f}")
            scores.append(rmse)
            
            oof_preds[valid_index] += y_pred / n_bags
            test_preds += model.predict(test_data) / kfold.get_n_splits() / n_bags
            
            del model
            gc.collect()
            
        print(f"#RMSE mean: {np.mean(scores):.7f} (+- {np.std(scores):.7f})")

    return oof_preds, test_preds

# %%
def objective_lgb(trial):
    global lgb_test
    global lgb_oof
    params_lgbm = {
        'num_leaves': trial.suggest_int('num_leaves', 20, 140),
        'learning_rate': trial.suggest_float('learning_rate', 0.15, 0.25),
        'n_estimators': trial.suggest_int('n_estimators', 3000, 4000),
        'max_depth': trial.suggest_int('max_depth', 5, 15),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 10, 30),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.7, 1),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.7, 1),
        'metric': 'root_mean_squared_error',
        'random_state': 42,
        'bagging_freq': 3,
        'device':'gpu',
        'verbose' : -1,
        'n_jobs': 4,
    }
    
    oof_preds_lgb, test_preds_lgb = cross_validate(params_lgbm, "lgb", X, y, test, n_splits = 5, n_bags = 3)

    rmse_score = np.sqrt(mean_squared_error(y, oof_preds_lgb))
    print(f"Trial {trial.number}, final RMSE: {rmse_score}")
    
    if trial.number == 0 or rmse_score < trial.study.best_value:
        lgb_test = test_preds_lgb
        lgb_oof = oof_preds_lgb
        print(f"Saved best test with RMSE score: {rmse_score}")
    
    return rmse_score

# %%
def objective_cat(trial):
    global cat_test
    global cat_oof
    params_cat = {
        'iterations': trial.suggest_int('iterations', 1000, 1500),
        'learning_rate': trial.suggest_float('learning_rate', 0.15, 0.25),
        'depth': trial.suggest_int('depth', 10, 15)
    }
    
    oof_preds_cat, test_preds_cat = cross_validate_cat(params_cat, X_cat, y_cat, test_cat, n_splits=5, n_bags=3)

    rmse_score = np.sqrt(mean_squared_error(y_cat, oof_preds_cat))
    print(f"Trial {trial.number}, final RMSE: {rmse_score}")
    
    if trial.number == 0 or rmse_score < trial.study.best_value:
        cat_test = test_preds_cat
        cat_oof = oof_preds_cat
        print(f"Saved best test with RMSE score: {rmse_score}")
    
    return rmse_score

# %%
def objective_xgb(trial):
    global xgb_test
    global xgb_oof
    params_xgb = {
        'learning_rate': trial.suggest_float('learning_rate', 0.15, 0.25),
        'n_estimators': trial.suggest_int('n_estimators', 1500, 2500),
        'max_depth': trial.suggest_int('max_depth', 10, 15),
        'reg_alpha': trial.suggest_int('req_alpha', 5, 20),
        'reg_lambda': trial.suggest_int('reg_lambda', 10, 20),
        'min_child_weight': trial.suggest_int('min_child_weight', 15, 25),                                    
        'eval_metric': 'rmse',
    }
    oof_preds_xgb, test_preds_xgb = cross_validate(params_xgb, "xgb", X, y, test, n_splits = 5, n_bags = 1)

    rmse_score = np.sqrt(mean_squared_error(y, oof_preds_xgb))
    print(f"Trial {trial.number}, final RMSE: {rmse_score}")
    
    if trial.number == 0 or rmse_score < trial.study.best_value:
        xgb_test = test_preds_xgb
        xgb_oof = oof_preds_xgb
        print(f"Saved best test with RMSE score: {rmse_score}")
    
    return rmse_score

# %%
X = train
y = X.pop('bg+1:00')

X_cat = train_cat
y_cat = X_cat.pop('bg+1:00')

callbacks = [log_evaluation(period=300), early_stopping(stopping_rounds=250)]

# %%
# Set up and run the Optuna study
#optuna.logging.set_verbosity(optuna.logging.WARNING)
#study = optuna.create_study(direction="minimize")
#study.optimize(objective_xgb, n_trials=4)
#print("Best parameters:", study.best_params)

# %%
best_params = {'learning_rate': 0.24301227753308435, 'n_estimators': 1837, 'max_depth': 12, 'req_alpha': 12, 'reg_lambda': 13, 'min_child_weight': 17, 'eval_metric': 'rmse',}
xgb_oof, xgb_test = cross_validate(best_params, "xgb", X, y, test, n_splits = 5, n_bags = 1)
# Out:
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [07:35:26] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "req_alpha" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [0]	validation_0-rmse:2.84129
# [300]	validation_0-rmse:1.53771
# [600]	validation_0-rmse:1.48037
# [900]	validation_0-rmse:1.46561
# [1200]	validation_0-rmse:1.46147
# [1500]	validation_0-rmse:1.45945
# [1800]	validation_0-rmse:1.45868
# [1836]	validation_0-rmse:1.45861
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [07:49:17] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# # Fold 0, bag 0: RMSE=1.45861
# #RMSE mean: 1.4586105 (+- 0.0000000)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [07:49:23] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "req_alpha" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [0]	validation_0-rmse:2.83149
# [300]	validation_0-rmse:1.52570
# [600]	validation_0-rmse:1.46509
# [900]	validation_0-rmse:1.45023
# [1200]	validation_0-rmse:1.44564
# [1500]	validation_0-rmse:1.44376
# [1800]	validation_0-rmse:1.44290
# [1836]	validation_0-rmse:1.44283
# # Fold 1, bag 0: RMSE=1.44283
# #RMSE mean: 1.4507209 (+- 0.0078896)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [08:03:07] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "req_alpha" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [0]	validation_0-rmse:2.84988
# [300]	validation_0-rmse:1.52983
# [600]	validation_0-rmse:1.46951
# [900]	validation_0-rmse:1.45565
# [1200]	validation_0-rmse:1.45091
# [1500]	validation_0-rmse:1.44933
# [1800]	validation_0-rmse:1.44852
# [1836]	validation_0-rmse:1.44846
# # Fold 2, bag 0: RMSE=1.44846
# #RMSE mean: 1.4499682 (+- 0.0065292)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [08:14:40] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "req_alpha" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [0]	validation_0-rmse:2.85258
# [300]	validation_0-rmse:1.51876
# [600]	validation_0-rmse:1.46496
# [900]	validation_0-rmse:1.45088
# [1200]	validation_0-rmse:1.44701
# [1500]	validation_0-rmse:1.44498
# [1800]	validation_0-rmse:1.44407
# [1836]	validation_0-rmse:1.44399
# # Fold 3, bag 0: RMSE=1.44399
# #RMSE mean: 1.4484737 (+- 0.0062188)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [08:26:14] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "req_alpha" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [0]	validation_0-rmse:2.84889
# [300]	validation_0-rmse:1.54357
# [600]	validation_0-rmse:1.48592
# [900]	validation_0-rmse:1.47279
# [1200]	validation_0-rmse:1.46850
# [1500]	validation_0-rmse:1.46693
# [1800]	validation_0-rmse:1.46595
# [1836]	validation_0-rmse:1.46588
# # Fold 4, bag 0: RMSE=1.46588
# #RMSE mean: 1.4519547 (+- 0.0089112)

# %%
sample_sub = pd.read_csv("/kaggle/input/brist1d/sample_submission.csv")
sample_sub['bg+1:00'] = xgb_test.astype(np.float16)
sample_sub['id'] = test_id
sample_sub.drop(1)
sample_sub.to_csv('submission_xgb.csv', index=False)
print(sample_sub.head())
# Out:
#          id    bg+1:00
# 0  p01_8459   8.539062
# 1  p01_8460   8.312500
# 2  p01_8461   8.406250
# 3  p01_8462  11.734375
# 4  p01_8463   7.371094

# %%
# Set up and run the Optuna study
#optuna.logging.set_verbosity(optuna.logging.WARNING)
#study = optuna.create_study(direction="minimize")
#study.optimize(objective_lgb, n_trials=8)
#print("Best parameters:", study.best_params)

# %%
best_params = {'num_leaves': 119, 'learning_rate': 0.23201091196307633, 'n_estimators': 3598, 'max_depth': 13, 'min_data_in_leaf': 17, 'feature_fraction': 0.8319694615799249, 'bagging_fraction': 0.7079871043022474, 'metric': 'root_mean_squared_error', 'random_state': 42,
'bagging_freq': 3,
'device':'gpu',
'verbose' : -1,
'n_jobs': 4,}
lgb_oof, lgb_test = cross_validate(best_params, "lgb", X, y, test, n_splits = 5, n_bags = 3)
# Out:
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# Training until validation scores don't improve for 250 rounds
# [300]	valid_0's rmse: 1.76164
# [600]	valid_0's rmse: 1.65978
# [900]	valid_0's rmse: 1.60433
# [1200]	valid_0's rmse: 1.57003
# [1500]	valid_0's rmse: 1.5479
# [1800]	valid_0's rmse: 1.53286
# [2100]	valid_0's rmse: 1.52205
# [2400]	valid_0's rmse: 1.51528
# [2700]	valid_0's rmse: 1.50984
# [3000]	valid_0's rmse: 1.50624
# [3300]	valid_0's rmse: 1.50355
# Did not meet early stopping. Best iteration is:
# [3598]	valid_0's rmse: 1.5014
# # Fold 0, bag 0: RMSE=1.50140
# Training until validation scores don't improve for 250 rounds
# [300]	valid_0's rmse: 1.75879
# [600]	valid_0's rmse: 1.65752
# [900]	valid_0's rmse: 1.60222
# [1200]	valid_0's rmse: 1.56796
# [1500]	valid_0's rmse: 1.54664
# [1800]	valid_0's rmse: 1.53218
# [2100]	valid_0's rmse: 1.52194
# [2400]	valid_0's rmse: 1.51475
# [2700]	valid_0's rmse: 1.50939
# [3000]	valid_0's rmse: 1.50571
# [3300]	valid_0's rmse: 1.50302
# Did not meet early stopping. Best iteration is:
# [3598]	valid_0's rmse: 1.50096
# # Fold 0, bag 1: RMSE=1.50096
# Training until validation scores don't improve for 250 rounds
# [300]	valid_0's rmse: 1.75553
# [600]	valid_0's rmse: 1.65804
# [900]	valid_0's rmse: 1.60018
# [1200]	valid_0's rmse: 1.5648
# [1500]	valid_0's rmse: 1.54431
# [1800]	valid_0's rmse: 1.53025
# [2100]	valid_0's rmse: 1.5198
# [2400]	valid_0's rmse: 1.51251
# [2700]	valid_0's rmse: 1.50675
# [3000]	valid_0's rmse: 1.50288
# [3300]	valid_0's rmse: 1.49998
# Did not meet early stopping. Best iteration is:
# [3598]	valid_0's rmse: 1.49788
# # Fold 0, bag 2: RMSE=1.49788
# #RMSE mean: 1.5000790 (+- 0.0015662)
# Training until validation scores don't improve for 250 rounds
# [300]	valid_0's rmse: 1.75279
# [600]	valid_0's rmse: 1.64789
# [900]	valid_0's rmse: 1.59285
# [1200]	valid_0's rmse: 1.55715
# [1500]	valid_0's rmse: 1.53452
# [1800]	valid_0's rmse: 1.51976
# [2100]	valid_0's rmse: 1.50986
# [2400]	valid_0's rmse: 1.50262
# [2700]	valid_0's rmse: 1.49738
# [3000]	valid_0's rmse: 1.49368
# [3300]	valid_0's rmse: 1.49088
# Did not meet early stopping. Best iteration is:
# [3598]	valid_0's rmse: 1.48861
# # Fold 1, bag 0: RMSE=1.48861
# Training until validation scores don't improve for 250 rounds
# [300]	valid_0's rmse: 1.74712
# [600]	valid_0's rmse: 1.64505
# [900]	valid_0's rmse: 1.58698
# [1200]	valid_0's rmse: 1.55269
# [1500]	valid_0's rmse: 1.52906
# [1800]	valid_0's rmse: 1.51299
# [2100]	valid_0's rmse: 1.50247
# [2400]	valid_0's rmse: 1.49532
# [2700]	valid_0's rmse: 1.49033
# [3000]	valid_0's rmse: 1.48655
# [3300]	valid_0's rmse: 1.48363
# Did not meet early stopping. Best iteration is:
# [3598]	valid_0's rmse: 1.48131
# # Fold 1, bag 1: RMSE=1.48131
# Training until validation scores don't improve for 250 rounds
# [300]	valid_0's rmse: 1.74985
# [600]	valid_0's rmse: 1.65244
# [900]	valid_0's rmse: 1.59875
# [1200]	valid_0's rmse: 1.56618
# [1500]	valid_0's rmse: 1.54276
# [1800]	valid_0's rmse: 1.5272
# [2100]	valid_0's rmse: 1.51766
# [2400]	valid_0's rmse: 1.51016
# [2700]	valid_0's rmse: 1.50516
# [3000]	valid_0's rmse: 1.50136
# [3300]	valid_0's rmse: 1.49865
# Did not meet early stopping. Best iteration is:
# [3598]	valid_0's rmse: 1.49654
# # Fold 1, bag 2: RMSE=1.49654
# #RMSE mean: 1.4944506 (+- 0.0072275)
# Training until validation scores don't improve for 250 rounds
# [300]	valid_0's rmse: 1.7483
# [600]	valid_0's rmse: 1.64601
# [900]	valid_0's rmse: 1.59342
# [1200]	valid_0's rmse: 1.55766
# [1500]	valid_0's rmse: 1.53544
# [1800]	valid_0's rmse: 1.52073
# [2100]	valid_0's rmse: 1.51066
# [2400]	valid_0's rmse: 1.50333
# [2700]	valid_0's rmse: 1.49797
# [3000]	valid_0's rmse: 1.49397
# [3300]	valid_0's rmse: 1.49144
# Did not meet early stopping. Best iteration is:
# [3598]	valid_0's rmse: 1.48939
# # Fold 2, bag 0: RMSE=1.48939
# Training until validation scores don't improve for 250 rounds
# [300]	valid_0's rmse: 1.75773
# [600]	valid_0's rmse: 1.64924
# [900]	valid_0's rmse: 1.5915
# [1200]	valid_0's rmse: 1.55441
# [1500]	valid_0's rmse: 1.53383
# [1800]	valid_0's rmse: 1.51833
# [2100]	valid_0's rmse: 1.5081
# [2400]	valid_0's rmse: 1.5008
# [2700]	valid_0's rmse: 1.49527
# [3000]	valid_0's rmse: 1.49152
# [3300]	valid_0's rmse: 1.48899
# Did not meet early stopping. Best iteration is:
# [3598]	valid_0's rmse: 1.48695
# # Fold 2, bag 1: RMSE=1.48695
# Training until validation scores don't improve for 250 rounds
# [300]	valid_0's rmse: 1.76008
# [600]	valid_0's rmse: 1.65577
# [900]	valid_0's rmse: 1.60017
# [1200]	valid_0's rmse: 1.56431
# [1500]	valid_0's rmse: 1.54339
# [1800]	valid_0's rmse: 1.52856
# [2100]	valid_0's rmse: 1.5185
# [2400]	valid_0's rmse: 1.51164
# [2700]	valid_0's rmse: 1.50648
# [3000]	valid_0's rmse: 1.50248
# [3300]	valid_0's rmse: 1.49966
# Did not meet early stopping. Best iteration is:
# [3598]	valid_0's rmse: 1.49764
# # Fold 2, bag 2: RMSE=1.49764
# #RMSE mean: 1.4934101 (+- 0.0066304)
# Training until validation scores don't improve for 250 rounds
# [300]	valid_0's rmse: 1.74532
# [600]	valid_0's rmse: 1.64241
# [900]	valid_0's rmse: 1.58825
# [1200]	valid_0's rmse: 1.55466
# [1500]	valid_0's rmse: 1.53359
# [1800]	valid_0's rmse: 1.5201
# [2100]	valid_0's rmse: 1.50967
# [2400]	valid_0's rmse: 1.50216
# [2700]	valid_0's rmse: 1.49668
# [3000]	valid_0's rmse: 1.49288
# [3300]	valid_0's rmse: 1.4903
# Did not meet early stopping. Best iteration is:
# [3598]	valid_0's rmse: 1.48822
# # Fold 3, bag 0: RMSE=1.48822
# Training until validation scores don't improve for 250 rounds
# [300]	valid_0's rmse: 1.74935
# [600]	valid_0's rmse: 1.64307
# [900]	valid_0's rmse: 1.58924
# [1200]	valid_0's rmse: 1.55323
# [1500]	valid_0's rmse: 1.53197
# [1800]	valid_0's rmse: 1.51747
# [2100]	valid_0's rmse: 1.50676
# [2400]	valid_0's rmse: 1.50018
# [2700]	valid_0's rmse: 1.49506
# [3000]	valid_0's rmse: 1.4913
# [3300]	valid_0's rmse: 1.48845
# Did not meet early stopping. Best iteration is:
# [3598]	valid_0's rmse: 1.4862
# # Fold 3, bag 1: RMSE=1.48620
# Training until validation scores don't improve for 250 rounds
# [300]	valid_0's rmse: 1.74899
# [600]	valid_0's rmse: 1.64441
# [900]	valid_0's rmse: 1.58957
# [1200]	valid_0's rmse: 1.55523
# [1500]	valid_0's rmse: 1.53322
# [1800]	valid_0's rmse: 1.51812
# [2100]	valid_0's rmse: 1.50911
# [2400]	valid_0's rmse: 1.50166
# [2700]	valid_0's rmse: 1.49631
# [3000]	valid_0's rmse: 1.49266
# [3300]	valid_0's rmse: 1.48985
# Did not meet early stopping. Best iteration is:
# [3598]	valid_0's rmse: 1.48789
# # Fold 3, bag 2: RMSE=1.48789
# #RMSE mean: 1.4919164 (+- 0.0063136)
# Training until validation scores don't improve for 250 rounds
# [300]	valid_0's rmse: 1.75883
# [600]	valid_0's rmse: 1.6573
# [900]	valid_0's rmse: 1.60424
# [1200]	valid_0's rmse: 1.57084
# [1500]	valid_0's rmse: 1.54945
# [1800]	valid_0's rmse: 1.53531
# [2100]	valid_0's rmse: 1.52479
# [2400]	valid_0's rmse: 1.51798
# [2700]	valid_0's rmse: 1.51335
# [3000]	valid_0's rmse: 1.50988
# [3300]	valid_0's rmse: 1.50713
# Did not meet early stopping. Best iteration is:
# [3598]	valid_0's rmse: 1.50514
# # Fold 4, bag 0: RMSE=1.50514
# Training until validation scores don't improve for 250 rounds
# [300]	valid_0's rmse: 1.76234
# [600]	valid_0's rmse: 1.66065
# [900]	valid_0's rmse: 1.61175
# [1200]	valid_0's rmse: 1.57489
# [1500]	valid_0's rmse: 1.55358
# [1800]	valid_0's rmse: 1.53898
# [2100]	valid_0's rmse: 1.52892
# [2400]	valid_0's rmse: 1.52116
# [2700]	valid_0's rmse: 1.51642
# [3000]	valid_0's rmse: 1.51312
# [3300]	valid_0's rmse: 1.51027
# Did not meet early stopping. Best iteration is:
# [3598]	valid_0's rmse: 1.50831
# # Fold 4, bag 1: RMSE=1.50831
# Training until validation scores don't improve for 250 rounds
# [300]	valid_0's rmse: 1.76069
# [600]	valid_0's rmse: 1.65812
# [900]	valid_0's rmse: 1.60218
# [1200]	valid_0's rmse: 1.56929
# [1500]	valid_0's rmse: 1.54797
# [1800]	valid_0's rmse: 1.53313
# [2100]	valid_0's rmse: 1.52282
# [2400]	valid_0's rmse: 1.51633
# [2700]	valid_0's rmse: 1.51146
# [3000]	valid_0's rmse: 1.5077
# [3300]	valid_0's rmse: 1.50525
# Did not meet early stopping. Best iteration is:
# [3598]	valid_0's rmse: 1.50335
# # Fold 4, bag 2: RMSE=1.50335
# #RMSE mean: 1.4946533 (+- 0.0079177)

# %%
sample_sub = pd.read_csv("/kaggle/input/brist1d/sample_submission.csv")
sample_sub['bg+1:00'] = lgb_test.astype(np.float16)
sample_sub['id'] = test_id
sample_sub.drop(1)
sample_sub.to_csv('submission_lgb.csv', index=False)
print(sample_sub.head())
# Out:
#          id    bg+1:00
# 0  p01_8459   8.234375
# 1  p01_8460   8.351562
# 2  p01_8461   8.320312
# 3  p01_8462  11.929688
# 4  p01_8463   8.031250

# %%
# Set up and run the Optuna study
optuna.logging.set_verbosity(optuna.logging.WARNING)
study = optuna.create_study(direction="minimize")
study.optimize(objective_cat, n_trials=3)
print("Best parameters:", study.best_params)
# Out:
# 0:	learn: 3.0229356	test: 3.0170545	best: 3.0170545 (0)	total: 4.7s	remaining: 1h 48m 29s
# 100:	learn: 1.9370012	test: 1.9666150	best: 1.9666150 (100)	total: 14.3s	remaining: 3m 1s
# 200:	learn: 1.7967225	test: 1.8863536	best: 1.8863536 (200)	total: 24s	remaining: 2m 21s
# 300:	learn: 1.6866723	test: 1.8352751	best: 1.8352751 (300)	total: 33.8s	remaining: 2m 1s
# 400:	learn: 1.5978030	test: 1.7955089	best: 1.7955089 (400)	total: 43.4s	remaining: 1m 46s
# 500:	learn: 1.5189096	test: 1.7651372	best: 1.7651372 (500)	total: 53.2s	remaining: 1m 33s
# 600:	learn: 1.4461044	test: 1.7355301	best: 1.7355301 (600)	total: 1m 2s	remaining: 1m 22s
# 700:	learn: 1.3818745	test: 1.7117340	best: 1.7117340 (700)	total: 1m 12s	remaining: 1m 11s
# 800:	learn: 1.3232171	test: 1.6915938	best: 1.6915938 (800)	total: 1m 22s	remaining: 1m
# 900:	learn: 1.2721699	test: 1.6753760	best: 1.6753760 (900)	total: 1m 32s	remaining: 49.7s
# 1000:	learn: 1.2207915	test: 1.6560842	best: 1.6560842 (1000)	total: 1m 42s	remaining: 39.2s
# 1100:	learn: 1.1728925	test: 1.6395760	best: 1.6395760 (1100)	total: 1m 51s	remaining: 28.9s
# 1200:	learn: 1.1273417	test: 1.6257521	best: 1.6257521 (1200)	total: 2m 1s	remaining: 18.7s
# 1300:	learn: 1.0857171	test: 1.6129234	best: 1.6129234 (1300)	total: 2m 11s	remaining: 8.59s
# 1385:	learn: 1.0520081	test: 1.6016684	best: 1.6016684 (1385)	total: 2m 19s	remaining: 0us
# bestTest = 1.601668426
# bestIteration = 1385
# # Fold 0, bag 0: RMSE=1.60167
# 0:	learn: 3.0229356	test: 3.0170545	best: 3.0170545 (0)	total: 104ms	remaining: 2m 23s
# 100:	learn: 1.9370012	test: 1.9666150	best: 1.9666150 (100)	total: 9.7s	remaining: 2m 3s
# 200:	learn: 1.7967225	test: 1.8863536	best: 1.8863536 (200)	total: 19.5s	remaining: 1m 54s
# 300:	learn: 1.6866723	test: 1.8352751	best: 1.8352751 (300)	total: 29.2s	remaining: 1m 45s
# 400:	learn: 1.5978030	test: 1.7955089	best: 1.7955089 (400)	total: 38.9s	remaining: 1m 35s
# 500:	learn: 1.5189096	test: 1.7651372	best: 1.7651372 (500)	total: 48.7s	remaining: 1m 25s
# 600:	learn: 1.4461044	test: 1.7355301	best: 1.7355301 (600)	total: 58.4s	remaining: 1m 16s
# 700:	learn: 1.3818745	test: 1.7117340	best: 1.7117340 (700)	total: 1m 8s	remaining: 1m 6s
# 800:	learn: 1.3232171	test: 1.6915938	best: 1.6915938 (800)	total: 1m 17s	remaining: 56.9s
# 900:	learn: 1.2721699	test: 1.6753760	best: 1.6753760 (900)	total: 1m 27s	remaining: 47.2s
# 1000:	learn: 1.2207915	test: 1.6560842	best: 1.6560842 (1000)	total: 1m 37s	remaining: 37.5s
# 1100:	learn: 1.1728925	test: 1.6395760	best: 1.6395760 (1100)	total: 1m 47s	remaining: 27.8s
# 1200:	learn: 1.1273417	test: 1.6257521	best: 1.6257521 (1200)	total: 1m 57s	remaining: 18s
# 1300:	learn: 1.0857171	test: 1.6129234	best: 1.6129234 (1300)	total: 2m 6s	remaining: 8.29s
# 1385:	learn: 1.0520081	test: 1.6016684	best: 1.6016684 (1385)	total: 2m 15s	remaining: 0us
# bestTest = 1.601668426
# bestIteration = 1385
# # Fold 0, bag 1: RMSE=1.60167
# 0:	learn: 3.0229356	test: 3.0170545	best: 3.0170545 (0)	total: 102ms	remaining: 2m 20s
# 100:	learn: 1.9370012	test: 1.9666150	best: 1.9666150 (100)	total: 9.7s	remaining: 2m 3s
# 200:	learn: 1.7967225	test: 1.8863536	best: 1.8863536 (200)	total: 19.4s	remaining: 1m 54s
# 300:	learn: 1.6866723	test: 1.8352751	best: 1.8352751 (300)	total: 29.2s	remaining: 1m 45s
# 400:	learn: 1.5978030	test: 1.7955089	best: 1.7955089 (400)	total: 38.8s	remaining: 1m 35s
# 500:	learn: 1.5189096	test: 1.7651372	best: 1.7651372 (500)	total: 48.6s	remaining: 1m 25s
# 600:	learn: 1.4461044	test: 1.7355301	best: 1.7355301 (600)	total: 58.4s	remaining: 1m 16s
# 700:	learn: 1.3818745	test: 1.7117340	best: 1.7117340 (700)	total: 1m 8s	remaining: 1m 6s
# 800:	learn: 1.3232171	test: 1.6915938	best: 1.6915938 (800)	total: 1m 17s	remaining: 56.9s
# 900:	learn: 1.2721699	test: 1.6753760	best: 1.6753760 (900)	total: 1m 27s	remaining: 47.2s
# 1000:	learn: 1.2207915	test: 1.6560842	best: 1.6560842 (1000)	total: 1m 37s	remaining: 37.5s
# 1100:	learn: 1.1728925	test: 1.6395760	best: 1.6395760 (1100)	total: 1m 47s	remaining: 27.8s
# 1200:	learn: 1.1273417	test: 1.6257521	best: 1.6257521 (1200)	total: 1m 57s	remaining: 18s
# 1300:	learn: 1.0857171	test: 1.6129234	best: 1.6129234 (1300)	total: 2m 6s	remaining: 8.29s
# 1385:	learn: 1.0520081	test: 1.6016684	best: 1.6016684 (1385)	total: 2m 15s	remaining: 0us
# bestTest = 1.601668426
# bestIteration = 1385
# # Fold 0, bag 2: RMSE=1.60167
# #RMSE mean: 1.6016684 (+- 0.0000000)
# 0:	learn: 3.0239482	test: 3.0081128	best: 3.0081128 (0)	total: 104ms	remaining: 2m 24s
# 100:	learn: 1.9354443	test: 1.9715482	best: 1.9715482 (100)	total: 9.7s	remaining: 2m 3s
# 200:	learn: 1.7890667	test: 1.8826136	best: 1.8826136 (200)	total: 19.3s	remaining: 1m 54s
# 300:	learn: 1.6821542	test: 1.8321622	best: 1.8321622 (300)	total: 29s	remaining: 1m 44s
# 400:	learn: 1.5892017	test: 1.7910704	best: 1.7910704 (400)	total: 38.8s	remaining: 1m 35s
# 500:	learn: 1.5147839	test: 1.7625630	best: 1.7625630 (500)	total: 48.6s	remaining: 1m 25s
# 600:	learn: 1.4416892	test: 1.7348805	best: 1.7348805 (600)	total: 58.4s	remaining: 1m 16s
# 700:	learn: 1.3752432	test: 1.7100855	best: 1.7100855 (700)	total: 1m 8s	remaining: 1m 6s
# 800:	learn: 1.3183626	test: 1.6900378	best: 1.6900378 (800)	total: 1m 18s	remaining: 57s
# 900:	learn: 1.2675012	test: 1.6719355	best: 1.6719355 (900)	total: 1m 27s	remaining: 47.2s
# 1000:	learn: 1.2171767	test: 1.6538924	best: 1.6538924 (1000)	total: 1m 37s	remaining: 37.5s
# 1100:	learn: 1.1657311	test: 1.6348357	best: 1.6348357 (1100)	total: 1m 47s	remaining: 27.8s
# 1200:	learn: 1.1232020	test: 1.6210995	best: 1.6210995 (1200)	total: 1m 57s	remaining: 18s
# 1300:	learn: 1.0826064	test: 1.6084999	best: 1.6084557 (1299)	total: 2m 6s	remaining: 8.29s
# 1385:	learn: 1.0501480	test: 1.5973765	best: 1.5973765 (1385)	total: 2m 15s	remaining: 0us
# bestTest = 1.597376454
# bestIteration = 1385
# # Fold 1, bag 0: RMSE=1.59738
# 0:	learn: 3.0239482	test: 3.0081128	best: 3.0081128 (0)	total: 104ms	remaining: 2m 23s
# 100:	learn: 1.9354443	test: 1.9715482	best: 1.9715482 (100)	total: 9.69s	remaining: 2m 3s
# 200:	learn: 1.7890667	test: 1.8826136	best: 1.8826136 (200)	total: 19.4s	remaining: 1m 54s
# 300:	learn: 1.6821542	test: 1.8321622	best: 1.8321622 (300)	total: 29.1s	remaining: 1m 45s
# 400:	learn: 1.5892017	test: 1.7910704	best: 1.7910704 (400)	total: 38.8s	remaining: 1m 35s
# 500:	learn: 1.5147839	test: 1.7625630	best: 1.7625630 (500)	total: 48.6s	remaining: 1m 25s
# 600:	learn: 1.4407770	test: 1.7341953	best: 1.7341953 (600)	total: 58.4s	remaining: 1m 16s
# 700:	learn: 1.3777177	test: 1.7103044	best: 1.7103044 (700)	total: 1m 8s	remaining: 1m 6s
# 800:	learn: 1.3207228	test: 1.6902824	best: 1.6902824 (800)	total: 1m 18s	remaining: 57s
# 900:	learn: 1.2693604	test: 1.6723102	best: 1.6723102 (900)	total: 1m 27s	remaining: 47.3s
# 1000:	learn: 1.2196415	test: 1.6551169	best: 1.6551169 (1000)	total: 1m 37s	remaining: 37.5s
# 1100:	learn: 1.1728882	test: 1.6385055	best: 1.6385055 (1100)	total: 1m 47s	remaining: 27.8s
# 1200:	learn: 1.1278817	test: 1.6228796	best: 1.6228796 (1200)	total: 1m 57s	remaining: 18.1s
# 1300:	learn: 1.0872575	test: 1.6095573	best: 1.6095573 (1300)	total: 2m 6s	remaining: 8.29s
# 1385:	learn: 1.0549142	test: 1.5985634	best: 1.5985634 (1385)	total: 2m 15s	remaining: 0us
# bestTest = 1.59856337
# bestIteration = 1385
# # Fold 1, bag 1: RMSE=1.59856
# 0:	learn: 3.0239482	test: 3.0081128	best: 3.0081128 (0)	total: 103ms	remaining: 2m 22s
# 100:	learn: 1.9354443	test: 1.9715482	best: 1.9715482 (100)	total: 9.71s	remaining: 2m 3s
# 200:	learn: 1.7890667	test: 1.8826136	best: 1.8826136 (200)	total: 19.4s	remaining: 1m 54s
# 300:	learn: 1.6821542	test: 1.8321622	best: 1.8321622 (300)	total: 29.1s	remaining: 1m 44s
# 400:	learn: 1.5892017	test: 1.7910704	best: 1.7910704 (400)	total: 38.8s	remaining: 1m 35s
# 500:	learn: 1.5147839	test: 1.7625630	best: 1.7625630 (500)	total: 48.5s	remaining: 1m 25s
# 600:	learn: 1.4407770	test: 1.7341953	best: 1.7341953 (600)	total: 58.2s	remaining: 1m 16s
# 700:	learn: 1.3777177	test: 1.7103044	best: 1.7103044 (700)	total: 1m 8s	remaining: 1m 6s
# 800:	learn: 1.3207228	test: 1.6902824	best: 1.6902824 (800)	total: 1m 17s	remaining: 56.9s
# 900:	learn: 1.2693604	test: 1.6723102	best: 1.6723102 (900)	total: 1m 27s	remaining: 47.2s
# 1000:	learn: 1.2196415	test: 1.6551169	best: 1.6551169 (1000)	total: 1m 37s	remaining: 37.5s
# 1100:	learn: 1.1728882	test: 1.6385055	best: 1.6385055 (1100)	total: 1m 47s	remaining: 27.8s
# 1200:	learn: 1.1278817	test: 1.6228796	best: 1.6228796 (1200)	total: 1m 57s	remaining: 18.1s
# 1300:	learn: 1.0872575	test: 1.6095573	best: 1.6095573 (1300)	total: 2m 6s	remaining: 8.29s
# 1385:	learn: 1.0549142	test: 1.5985634	best: 1.5985634 (1385)	total: 2m 15s	remaining: 0us
# bestTest = 1.59856337
# bestIteration = 1385
# # Fold 1, bag 2: RMSE=1.59856
# #RMSE mean: 1.5999181 (+- 0.0017945)
# 0:	learn: 3.0215034	test: 3.0263483	best: 3.0263483 (0)	total: 98.7ms	remaining: 2m 16s
# 100:	learn: 1.9416361	test: 1.9870872	best: 1.9870872 (100)	total: 9.71s	remaining: 2m 3s
# 200:	learn: 1.7950921	test: 1.8935514	best: 1.8935514 (200)	total: 19.4s	remaining: 1m 54s
# 300:	learn: 1.6844122	test: 1.8384686	best: 1.8384686 (300)	total: 29.2s	remaining: 1m 45s
# 400:	learn: 1.5906375	test: 1.7953966	best: 1.7953966 (400)	total: 39s	remaining: 1m 35s
# 500:	learn: 1.5129977	test: 1.7646002	best: 1.7646002 (500)	total: 48.7s	remaining: 1m 25s
# 600:	learn: 1.4428426	test: 1.7362721	best: 1.7362721 (600)	total: 58.5s	remaining: 1m 16s
# 700:	learn: 1.3780321	test: 1.7114464	best: 1.7114464 (700)	total: 1m 8s	remaining: 1m 6s
# 800:	learn: 1.3222623	test: 1.6904126	best: 1.6904126 (800)	total: 1m 17s	remaining: 56.9s
# 900:	learn: 1.2707393	test: 1.6728608	best: 1.6728608 (900)	total: 1m 27s	remaining: 47.2s
# 1000:	learn: 1.2201167	test: 1.6548528	best: 1.6548528 (1000)	total: 1m 37s	remaining: 37.5s
# 1100:	learn: 1.1722011	test: 1.6367699	best: 1.6367699 (1100)	total: 1m 47s	remaining: 27.8s
# 1200:	learn: 1.1273940	test: 1.6202687	best: 1.6202687 (1200)	total: 1m 57s	remaining: 18s
# 1300:	learn: 1.0882809	test: 1.6080613	best: 1.6080613 (1300)	total: 2m 6s	remaining: 8.29s
# 1385:	learn: 1.0561501	test: 1.5981531	best: 1.5981531 (1385)	total: 2m 15s	remaining: 0us
# bestTest = 1.59815314
# bestIteration = 1385
# # Fold 2, bag 0: RMSE=1.59815
# 0:	learn: 3.0215034	test: 3.0263483	best: 3.0263483 (0)	total: 98.2ms	remaining: 2m 16s
# 100:	learn: 1.9416361	test: 1.9870872	best: 1.9870872 (100)	total: 9.75s	remaining: 2m 4s
# 200:	learn: 1.7950921	test: 1.8935514	best: 1.8935514 (200)	total: 19.4s	remaining: 1m 54s
# 300:	learn: 1.6844122	test: 1.8384686	best: 1.8384686 (300)	total: 29.2s	remaining: 1m 45s
# 400:	learn: 1.5906375	test: 1.7953966	best: 1.7953966 (400)	total: 38.9s	remaining: 1m 35s
# 500:	learn: 1.5129977	test: 1.7646002	best: 1.7646002 (500)	total: 48.7s	remaining: 1m 26s
# 600:	learn: 1.4428426	test: 1.7362721	best: 1.7362721 (600)	total: 58.5s	remaining: 1m 16s
# 700:	learn: 1.3780321	test: 1.7114464	best: 1.7114464 (700)	total: 1m 8s	remaining: 1m 6s
# 800:	learn: 1.3222623	test: 1.6904126	best: 1.6904126 (800)	total: 1m 17s	remaining: 56.9s
# 900:	learn: 1.2707393	test: 1.6728608	best: 1.6728608 (900)	total: 1m 27s	remaining: 47.2s
# 1000:	learn: 1.2201167	test: 1.6548528	best: 1.6548528 (1000)	total: 1m 37s	remaining: 37.5s
# 1100:	learn: 1.1722011	test: 1.6367699	best: 1.6367699 (1100)	total: 1m 47s	remaining: 27.8s
# 1200:	learn: 1.1273940	test: 1.6202687	best: 1.6202687 (1200)	total: 1m 57s	remaining: 18s
# 1300:	learn: 1.0882809	test: 1.6080613	best: 1.6080613 (1300)	total: 2m 6s	remaining: 8.29s
# 1385:	learn: 1.0561501	test: 1.5981531	best: 1.5981531 (1385)	total: 2m 15s	remaining: 0us
# bestTest = 1.59815314
# bestIteration = 1385
# # Fold 2, bag 1: RMSE=1.59815
# 0:	learn: 3.0215034	test: 3.0263483	best: 3.0263483 (0)	total: 99ms	remaining: 2m 17s
# 100:	learn: 1.9416361	test: 1.9870872	best: 1.9870872 (100)	total: 9.73s	remaining: 2m 3s
# 200:	learn: 1.7950921	test: 1.8935514	best: 1.8935514 (200)	total: 19.4s	remaining: 1m 54s
# 300:	learn: 1.6844122	test: 1.8384686	best: 1.8384686 (300)	total: 29.2s	remaining: 1m 45s
# 400:	learn: 1.5906375	test: 1.7953966	best: 1.7953966 (400)	total: 38.9s	remaining: 1m 35s
# 500:	learn: 1.5115185	test: 1.7638294	best: 1.7638294 (500)	total: 48.7s	remaining: 1m 25s
# 600:	learn: 1.4386026	test: 1.7336553	best: 1.7336553 (600)	total: 58.5s	remaining: 1m 16s
# 700:	learn: 1.3764675	test: 1.7093845	best: 1.7093845 (700)	total: 1m 8s	remaining: 1m 6s
# 800:	learn: 1.3163747	test: 1.6852263	best: 1.6852263 (800)	total: 1m 17s	remaining: 56.9s
# 900:	learn: 1.2666698	test: 1.6687186	best: 1.6687186 (900)	total: 1m 27s	remaining: 47.2s
# 1000:	learn: 1.2156995	test: 1.6506630	best: 1.6506630 (1000)	total: 1m 37s	remaining: 37.5s
# 1100:	learn: 1.1678195	test: 1.6332341	best: 1.6332341 (1100)	total: 1m 47s	remaining: 27.8s
# 1200:	learn: 1.1229986	test: 1.6168165	best: 1.6168165 (1200)	total: 1m 57s	remaining: 18s
# 1300:	learn: 1.0823268	test: 1.6029738	best: 1.6029553 (1299)	total: 2m 6s	remaining: 8.29s
# 1385:	learn: 1.0510591	test: 1.5925746	best: 1.5925670 (1384)	total: 2m 15s	remaining: 0us
# bestTest = 1.592567044
# bestIteration = 1384
# Shrink model to first 1385 iterations.
# # Fold 2, bag 2: RMSE=1.59257
# #RMSE mean: 1.5987091 (+- 0.0027169)
# 0:	learn: 3.0197613	test: 3.0297609	best: 3.0297609 (0)	total: 98.5ms	remaining: 2m 16s
# 100:	learn: 1.9375028	test: 1.9590393	best: 1.9590393 (100)	total: 9.69s	remaining: 2m 3s
# 200:	learn: 1.7943063	test: 1.8752575	best: 1.8752575 (200)	total: 19.4s	remaining: 1m 54s
# 300:	learn: 1.6902688	test: 1.8237119	best: 1.8237119 (300)	total: 29.1s	remaining: 1m 45s
# 400:	learn: 1.5994848	test: 1.7848172	best: 1.7848172 (400)	total: 38.9s	remaining: 1m 35s
# 500:	learn: 1.5180929	test: 1.7520312	best: 1.7520312 (500)	total: 48.7s	remaining: 1m 26s
# 600:	learn: 1.4489077	test: 1.7275234	best: 1.7275234 (600)	total: 58.4s	remaining: 1m 16s
# 700:	learn: 1.3822969	test: 1.7029516	best: 1.7029516 (700)	total: 1m 8s	remaining: 1m 6s
# 800:	learn: 1.3230102	test: 1.6802929	best: 1.6802929 (800)	total: 1m 17s	remaining: 56.9s
# 900:	learn: 1.2672259	test: 1.6612860	best: 1.6612860 (900)	total: 1m 27s	remaining: 47.2s
# 1000:	learn: 1.2185809	test: 1.6439107	best: 1.6439107 (1000)	total: 1m 37s	remaining: 37.5s
# 1100:	learn: 1.1727852	test: 1.6290129	best: 1.6290129 (1100)	total: 1m 47s	remaining: 27.8s
# 1200:	learn: 1.1284309	test: 1.6144427	best: 1.6144427 (1200)	total: 1m 56s	remaining: 18s
# 1300:	learn: 1.0872363	test: 1.6003872	best: 1.6003872 (1300)	total: 2m 6s	remaining: 8.29s
# 1385:	learn: 1.0530946	test: 1.5893106	best: 1.5893106 (1385)	total: 2m 15s	remaining: 0us
# bestTest = 1.589310581
# bestIteration = 1385
# # Fold 3, bag 0: RMSE=1.58931
# 0:	learn: 3.0197613	test: 3.0297609	best: 3.0297609 (0)	total: 98.8ms	remaining: 2m 16s
# 100:	learn: 1.9375028	test: 1.9590393	best: 1.9590393 (100)	total: 9.67s	remaining: 2m 3s
# 200:	learn: 1.7933775	test: 1.8739325	best: 1.8739325 (200)	total: 19.4s	remaining: 1m 54s
# 300:	learn: 1.6819556	test: 1.8191816	best: 1.8191816 (300)	total: 29.1s	remaining: 1m 45s
# 400:	learn: 1.5937774	test: 1.7811042	best: 1.7811042 (400)	total: 38.9s	remaining: 1m 35s
# 500:	learn: 1.5131750	test: 1.7489593	best: 1.7489593 (500)	total: 48.7s	remaining: 1m 25s
# 600:	learn: 1.4413428	test: 1.7219912	best: 1.7219912 (600)	total: 58.4s	remaining: 1m 16s
# 700:	learn: 1.3759540	test: 1.6970206	best: 1.6970206 (700)	total: 1m 8s	remaining: 1m 6s
# 800:	learn: 1.3211813	test: 1.6791137	best: 1.6791137 (800)	total: 1m 17s	remaining: 56.9s
# 900:	learn: 1.2661774	test: 1.6602248	best: 1.6602248 (900)	total: 1m 27s	remaining: 47.2s
# 1000:	learn: 1.2158473	test: 1.6404990	best: 1.6404990 (1000)	total: 1m 37s	remaining: 37.5s
# 1100:	learn: 1.1717661	test: 1.6260300	best: 1.6260300 (1100)	total: 1m 47s	remaining: 27.7s
# 1200:	learn: 1.1283838	test: 1.6114010	best: 1.6114010 (1200)	total: 1m 56s	remaining: 18s
# 1300:	learn: 1.0883240	test: 1.5974258	best: 1.5974258 (1300)	total: 2m 6s	remaining: 8.29s
# 1385:	learn: 1.0572436	test: 1.5876881	best: 1.5876881 (1385)	total: 2m 15s	remaining: 0us
# bestTest = 1.587688136
# bestIteration = 1385
# # Fold 3, bag 1: RMSE=1.58769
# 0:	learn: 3.0197613	test: 3.0297609	best: 3.0297609 (0)	total: 100ms	remaining: 2m 18s
# 100:	learn: 1.9375028	test: 1.9590393	best: 1.9590393 (100)	total: 9.7s	remaining: 2m 3s
# 200:	learn: 1.7933775	test: 1.8739325	best: 1.8739325 (200)	total: 19.4s	remaining: 1m 54s
# 300:	learn: 1.6819556	test: 1.8191816	best: 1.8191816 (300)	total: 29.1s	remaining: 1m 44s
# 400:	learn: 1.5937774	test: 1.7811042	best: 1.7811042 (400)	total: 38.8s	remaining: 1m 35s
# 500:	learn: 1.5131750	test: 1.7489593	best: 1.7489593 (500)	total: 48.7s	remaining: 1m 25s
# 600:	learn: 1.4413428	test: 1.7219912	best: 1.7219912 (600)	total: 58.4s	remaining: 1m 16s
# 700:	learn: 1.3759540	test: 1.6970206	best: 1.6970206 (700)	total: 1m 8s	remaining: 1m 6s
# 800:	learn: 1.3211813	test: 1.6791137	best: 1.6791137 (800)	total: 1m 17s	remaining: 56.9s
# 900:	learn: 1.2661774	test: 1.6602248	best: 1.6602248 (900)	total: 1m 27s	remaining: 47.2s
# 1000:	learn: 1.2158473	test: 1.6404990	best: 1.6404990 (1000)	total: 1m 37s	remaining: 37.4s
# 1100:	learn: 1.1717661	test: 1.6260300	best: 1.6260300 (1100)	total: 1m 47s	remaining: 27.7s
# 1200:	learn: 1.1283838	test: 1.6114010	best: 1.6114010 (1200)	total: 1m 56s	remaining: 18s
# 1300:	learn: 1.0883240	test: 1.5974258	best: 1.5974258 (1300)	total: 2m 6s	remaining: 8.27s
# 1385:	learn: 1.0572436	test: 1.5876881	best: 1.5876881 (1385)	total: 2m 15s	remaining: 0us
# bestTest = 1.587688136
# bestIteration = 1385
# # Fold 3, bag 2: RMSE=1.58769
# #RMSE mean: 1.5960890 (+- 0.0051260)
# 0:	learn: 3.0218883	test: 3.0279642	best: 3.0279642 (0)	total: 93.4ms	remaining: 2m 9s
# 100:	learn: 1.9350718	test: 1.9834337	best: 1.9834337 (100)	total: 9.73s	remaining: 2m 3s
# 200:	learn: 1.7915053	test: 1.8955517	best: 1.8955517 (200)	total: 19.5s	remaining: 1m 55s
# 300:	learn: 1.6791776	test: 1.8388268	best: 1.8388268 (300)	total: 29.4s	remaining: 1m 45s
# 400:	learn: 1.5896695	test: 1.8012740	best: 1.8012740 (400)	total: 39.1s	remaining: 1m 35s
# 500:	learn: 1.5112675	test: 1.7686772	best: 1.7686772 (500)	total: 48.8s	remaining: 1m 26s
# 600:	learn: 1.4400654	test: 1.7406551	best: 1.7406551 (600)	total: 58.5s	remaining: 1m 16s
# 700:	learn: 1.3760457	test: 1.7155871	best: 1.7155871 (700)	total: 1m 8s	remaining: 1m 6s
# 800:	learn: 1.3178637	test: 1.6947112	best: 1.6947112 (800)	total: 1m 18s	remaining: 57s
# 900:	learn: 1.2650522	test: 1.6761468	best: 1.6761468 (900)	total: 1m 27s	remaining: 47.3s
# 1000:	learn: 1.2148541	test: 1.6586878	best: 1.6586878 (1000)	total: 1m 37s	remaining: 37.6s
# 1100:	learn: 1.1702564	test: 1.6433943	best: 1.6433943 (1100)	total: 1m 47s	remaining: 27.8s
# 1200:	learn: 1.1255054	test: 1.6271975	best: 1.6271975 (1200)	total: 1m 57s	remaining: 18.1s
# 1300:	learn: 1.0844643	test: 1.6132804	best: 1.6132804 (1300)	total: 2m 7s	remaining: 8.3s
# 1385:	learn: 1.0528034	test: 1.6035665	best: 1.6035665 (1385)	total: 2m 15s	remaining: 0us
# bestTest = 1.603566543
# bestIteration = 1385
# # Fold 4, bag 0: RMSE=1.60357
# 0:	learn: 3.0218883	test: 3.0279642	best: 3.0279642 (0)	total: 91.5ms	remaining: 2m 6s
# 100:	learn: 1.9350718	test: 1.9834337	best: 1.9834337 (100)	total: 9.75s	remaining: 2m 3s
# 200:	learn: 1.7915053	test: 1.8955517	best: 1.8955517 (200)	total: 19.5s	remaining: 1m 54s
# 300:	learn: 1.6791776	test: 1.8388268	best: 1.8388268 (300)	total: 29.3s	remaining: 1m 45s
# 400:	learn: 1.5896695	test: 1.8012740	best: 1.8012740 (400)	total: 39s	remaining: 1m 35s
# 500:	learn: 1.5112675	test: 1.7686772	best: 1.7686772 (500)	total: 48.8s	remaining: 1m 26s
# 600:	learn: 1.4400654	test: 1.7406551	best: 1.7406551 (600)	total: 58.5s	remaining: 1m 16s
# 700:	learn: 1.3760457	test: 1.7155871	best: 1.7155871 (700)	total: 1m 8s	remaining: 1m 6s
# 800:	learn: 1.3178637	test: 1.6947112	best: 1.6947112 (800)	total: 1m 18s	remaining: 57s
# 900:	learn: 1.2650522	test: 1.6761468	best: 1.6761468 (900)	total: 1m 27s	remaining: 47.3s
# 1000:	learn: 1.2157971	test: 1.6586857	best: 1.6586857 (1000)	total: 1m 37s	remaining: 37.6s
# 1100:	learn: 1.1705149	test: 1.6438444	best: 1.6438444 (1100)	total: 1m 47s	remaining: 27.8s
# 1200:	learn: 1.1266422	test: 1.6277402	best: 1.6277402 (1200)	total: 1m 57s	remaining: 18.1s
# 1300:	learn: 1.0866683	test: 1.6143787	best: 1.6143787 (1300)	total: 2m 7s	remaining: 8.3s
# 1385:	learn: 1.0534426	test: 1.6034638	best: 1.6034638 (1385)	total: 2m 15s	remaining: 0us
# bestTest = 1.603463785
# bestIteration = 1385
# # Fold 4, bag 1: RMSE=1.60346
# 0:	learn: 3.0218883	test: 3.0279642	best: 3.0279642 (0)	total: 92ms	remaining: 2m 7s
# 100:	learn: 1.9350718	test: 1.9834337	best: 1.9834337 (100)	total: 9.71s	remaining: 2m 3s
# 200:	learn: 1.7915053	test: 1.8955517	best: 1.8955517 (200)	total: 19.4s	remaining: 1m 54s
# 300:	learn: 1.6791776	test: 1.8388268	best: 1.8388268 (300)	total: 29.2s	remaining: 1m 45s
# 400:	learn: 1.5896695	test: 1.8012740	best: 1.8012740 (400)	total: 39s	remaining: 1m 35s
# 500:	learn: 1.5112675	test: 1.7686772	best: 1.7686772 (500)	total: 48.8s	remaining: 1m 26s
# 600:	learn: 1.4400654	test: 1.7406551	best: 1.7406551 (600)	total: 58.6s	remaining: 1m 16s
# 700:	learn: 1.3760457	test: 1.7155871	best: 1.7155871 (700)	total: 1m 8s	remaining: 1m 6s
# 800:	learn: 1.3178637	test: 1.6947112	best: 1.6947112 (800)	total: 1m 18s	remaining: 57s
# 900:	learn: 1.2650522	test: 1.6761468	best: 1.6761468 (900)	total: 1m 27s	remaining: 47.3s
# 1000:	learn: 1.2157971	test: 1.6586857	best: 1.6586857 (1000)	total: 1m 37s	remaining: 37.6s
# 1100:	learn: 1.1705149	test: 1.6438444	best: 1.6438444 (1100)	total: 1m 47s	remaining: 27.8s
# 1200:	learn: 1.1266422	test: 1.6277402	best: 1.6277402 (1200)	total: 1m 57s	remaining: 18.1s
# 1300:	learn: 1.0866683	test: 1.6143787	best: 1.6143787 (1300)	total: 2m 7s	remaining: 8.3s
# 1385:	learn: 1.0534426	test: 1.6034638	best: 1.6034638 (1385)	total: 2m 15s	remaining: 0us
# bestTest = 1.603463785
# bestIteration = 1385
# # Fold 4, bag 2: RMSE=1.60346
# #RMSE mean: 1.5975709 (+- 0.0054593)
# Trial 0, final RMSE: 1.5895459136952834
# Saved best test with RMSE score: 1.5895459136952834
# 0:	learn: 3.0182991	test: 3.0139160	best: 3.0139160 (0)	total: 388ms	remaining: 6m 50s
# 100:	learn: 1.6266923	test: 1.8483123	best: 1.8483123 (100)	total: 41.1s	remaining: 6m 29s
# 200:	learn: 1.2829026	test: 1.7198963	best: 1.7198963 (200)	total: 1m 21s	remaining: 5m 49s
# 300:	learn: 1.0376718	test: 1.6372204	best: 1.6372204 (300)	total: 2m 3s	remaining: 5m 9s
# 400:	learn: 0.8650473	test: 1.5831790	best: 1.5831790 (400)	total: 2m 44s	remaining: 4m 28s
# 500:	learn: 0.7423087	test: 1.5479774	best: 1.5479774 (500)	total: 3m 24s	remaining: 3m 47s
# 600:	learn: 0.6351603	test: 1.5186030	best: 1.5186030 (600)	total: 4m 6s	remaining: 3m 7s
# 700:	learn: 0.5508711	test: 1.4955303	best: 1.4955303 (700)	total: 4m 47s	remaining: 2m 26s
# 800:	learn: 0.4813123	test: 1.4778941	best: 1.4778941 (800)	total: 5m 28s	remaining: 1m 45s
# 900:	learn: 0.4258847	test: 1.4643701	best: 1.4643701 (900)	total: 6m 9s	remaining: 1m 4s
# 1000:	learn: 0.3776468	test: 1.4531053	best: 1.4531053 (1000)	total: 6m 50s	remaining: 23.4s
# 1057:	learn: 0.3515193	test: 1.4472386	best: 1.4472386 (1057)	total: 7m 14s	remaining: 0us
# bestTest = 1.447238574
# bestIteration = 1057
# # Fold 0, bag 0: RMSE=1.44724
# 0:	learn: 3.0182991	test: 3.0139160	best: 3.0139160 (0)	total: 390ms	remaining: 6m 52s
# 100:	learn: 1.6266923	test: 1.8483123	best: 1.8483123 (100)	total: 41.1s	remaining: 6m 29s
# 200:	learn: 1.2829026	test: 1.7198963	best: 1.7198963 (200)	total: 1m 22s	remaining: 5m 49s
# 300:	learn: 1.0376718	test: 1.6372204	best: 1.6372204 (300)	total: 2m 3s	remaining: 5m 10s
# 400:	learn: 0.8650473	test: 1.5831790	best: 1.5831790 (400)	total: 2m 44s	remaining: 4m 29s
# 500:	learn: 0.7423087	test: 1.5479774	best: 1.5479774 (500)	total: 3m 25s	remaining: 3m 48s
# 600:	learn: 0.6351603	test: 1.5186030	best: 1.5186030 (600)	total: 4m 6s	remaining: 3m 7s
# 700:	learn: 0.5508711	test: 1.4955303	best: 1.4955303 (700)	total: 4m 47s	remaining: 2m 26s
# 800:	learn: 0.4813123	test: 1.4778941	best: 1.4778941 (800)	total: 5m 28s	remaining: 1m 45s
# 900:	learn: 0.4258847	test: 1.4643701	best: 1.4643701 (900)	total: 6m 9s	remaining: 1m 4s
# 1000:	learn: 0.3776468	test: 1.4531053	best: 1.4531053 (1000)	total: 6m 50s	remaining: 23.4s
# 1057:	learn: 0.3515193	test: 1.4472386	best: 1.4472386 (1057)	total: 7m 14s	remaining: 0us
# bestTest = 1.447238574
# bestIteration = 1057
# # Fold 0, bag 1: RMSE=1.44724
# 0:	learn: 3.0182991	test: 3.0139160	best: 3.0139160 (0)	total: 388ms	remaining: 6m 50s
# 100:	learn: 1.6266923	test: 1.8483123	best: 1.8483123 (100)	total: 41.1s	remaining: 6m 29s
# 200:	learn: 1.2829026	test: 1.7198963	best: 1.7198963 (200)	total: 1m 22s	remaining: 5m 49s
# 300:	learn: 1.0376718	test: 1.6372204	best: 1.6372204 (300)	total: 2m 3s	remaining: 5m 10s
# 400:	learn: 0.8650473	test: 1.5831790	best: 1.5831790 (400)	total: 2m 44s	remaining: 4m 29s
# 500:	learn: 0.7423087	test: 1.5479774	best: 1.5479774 (500)	total: 3m 25s	remaining: 3m 48s
# 600:	learn: 0.6351603	test: 1.5186030	best: 1.5186030 (600)	total: 4m 6s	remaining: 3m 7s
# 700:	learn: 0.5508711	test: 1.4955303	best: 1.4955303 (700)	total: 4m 47s	remaining: 2m 26s
# 800:	learn: 0.4813123	test: 1.4778941	best: 1.4778941 (800)	total: 5m 28s	remaining: 1m 45s
# 900:	learn: 0.4258847	test: 1.4643701	best: 1.4643701 (900)	total: 6m 9s	remaining: 1m 4s
# 1000:	learn: 0.3776468	test: 1.4531053	best: 1.4531053 (1000)	total: 6m 51s	remaining: 23.4s
# 1057:	learn: 0.3515193	test: 1.4472386	best: 1.4472386 (1057)	total: 7m 14s	remaining: 0us
# bestTest = 1.447238574
# bestIteration = 1057
# # Fold 0, bag 2: RMSE=1.44724
# #RMSE mean: 1.4472387 (+- 0.0000000)
# 0:	learn: 3.0191132	test: 3.0035146	best: 3.0035146 (0)	total: 388ms	remaining: 6m 50s
# 100:	learn: 1.6299298	test: 1.8498739	best: 1.8498739 (100)	total: 41.3s	remaining: 6m 31s
# 200:	learn: 1.2895561	test: 1.7085418	best: 1.7085418 (200)	total: 1m 22s	remaining: 5m 49s
# 300:	learn: 1.0574281	test: 1.6326277	best: 1.6326277 (300)	total: 2m 3s	remaining: 5m 9s
# 400:	learn: 0.8822101	test: 1.5761322	best: 1.5761322 (400)	total: 2m 44s	remaining: 4m 28s
# 500:	learn: 0.7434035	test: 1.5349929	best: 1.5349929 (500)	total: 3m 25s	remaining: 3m 48s
# 600:	learn: 0.6361408	test: 1.5040592	best: 1.5040592 (600)	total: 4m 6s	remaining: 3m 7s
# 700:	learn: 0.5503270	test: 1.4814751	best: 1.4814751 (700)	total: 4m 48s	remaining: 2m 26s
# 800:	learn: 0.4815554	test: 1.4636161	best: 1.4636161 (800)	total: 5m 28s	remaining: 1m 45s
# 900:	learn: 0.4218693	test: 1.4498562	best: 1.4498562 (900)	total: 6m 10s	remaining: 1m 4s
# 1000:	learn: 0.3732439	test: 1.4383739	best: 1.4383739 (1000)	total: 6m 51s	remaining: 23.4s
# 1057:	learn: 0.3487253	test: 1.4334778	best: 1.4334778 (1057)	total: 7m 15s	remaining: 0us
# bestTest = 1.43347785
# bestIteration = 1057
# # Fold 1, bag 0: RMSE=1.43348
# 0:	learn: 3.0191132	test: 3.0035146	best: 3.0035146 (0)	total: 391ms	remaining: 6m 53s
# 100:	learn: 1.6299298	test: 1.8498739	best: 1.8498739 (100)	total: 41.3s	remaining: 6m 31s
# 200:	learn: 1.2895561	test: 1.7085418	best: 1.7085418 (200)	total: 1m 22s	remaining: 5m 49s
# 300:	learn: 1.0574281	test: 1.6326277	best: 1.6326277 (300)	total: 2m 2s	remaining: 5m 9s
# 400:	learn: 0.8822101	test: 1.5761322	best: 1.5761322 (400)	total: 2m 44s	remaining: 4m 28s
# 500:	learn: 0.7434035	test: 1.5349929	best: 1.5349929 (500)	total: 3m 25s	remaining: 3m 48s
# 600:	learn: 0.6361408	test: 1.5040592	best: 1.5040592 (600)	total: 4m 6s	remaining: 3m 7s
# 700:	learn: 0.5503270	test: 1.4814751	best: 1.4814751 (700)	total: 4m 48s	remaining: 2m 26s
# 800:	learn: 0.4815554	test: 1.4636161	best: 1.4636161 (800)	total: 5m 29s	remaining: 1m 45s
# 900:	learn: 0.4218699	test: 1.4498564	best: 1.4498564 (900)	total: 6m 10s	remaining: 1m 4s
# 1000:	learn: 0.3732442	test: 1.4383742	best: 1.4383742 (1000)	total: 6m 51s	remaining: 23.4s
# 1057:	learn: 0.3487255	test: 1.4334779	best: 1.4334779 (1057)	total: 7m 15s	remaining: 0us
# bestTest = 1.433477927
# bestIteration = 1057
# # Fold 1, bag 1: RMSE=1.43348
# 0:	learn: 3.0191132	test: 3.0035146	best: 3.0035146 (0)	total: 392ms	remaining: 6m 54s
# 100:	learn: 1.6299298	test: 1.8498739	best: 1.8498739 (100)	total: 41.4s	remaining: 6m 32s
# 200:	learn: 1.2895561	test: 1.7085418	best: 1.7085418 (200)	total: 1m 22s	remaining: 5m 51s
# 300:	learn: 1.0574281	test: 1.6326277	best: 1.6326277 (300)	total: 2m 3s	remaining: 5m 10s
# 400:	learn: 0.8822101	test: 1.5761322	best: 1.5761322 (400)	total: 2m 44s	remaining: 4m 29s
# 500:	learn: 0.7434035	test: 1.5349929	best: 1.5349929 (500)	total: 3m 26s	remaining: 3m 49s
# 600:	learn: 0.6361408	test: 1.5040592	best: 1.5040592 (600)	total: 4m 7s	remaining: 3m 8s
# 700:	learn: 0.5503270	test: 1.4814751	best: 1.4814751 (700)	total: 4m 49s	remaining: 2m 27s
# 800:	learn: 0.4815554	test: 1.4636161	best: 1.4636161 (800)	total: 5m 30s	remaining: 1m 46s
# 900:	learn: 0.4218699	test: 1.4498564	best: 1.4498564 (900)	total: 6m 11s	remaining: 1m 4s
# 1000:	learn: 0.3732442	test: 1.4383742	best: 1.4383742 (1000)	total: 6m 52s	remaining: 23.5s
# 1057:	learn: 0.3487255	test: 1.4334779	best: 1.4334779 (1057)	total: 7m 16s	remaining: 0us
# bestTest = 1.433477927
# bestIteration = 1057
# # Fold 1, bag 2: RMSE=1.43348
# #RMSE mean: 1.4403583 (+- 0.0068803)
# 0:	learn: 3.0143435	test: 3.0197666	best: 3.0197666 (0)	total: 405ms	remaining: 7m 7s
# 100:	learn: 1.6144302	test: 1.8495330	best: 1.8495330 (100)	total: 41.6s	remaining: 6m 33s
# 200:	learn: 1.2753050	test: 1.7190972	best: 1.7190972 (200)	total: 1m 22s	remaining: 5m 51s
# 300:	learn: 1.0473527	test: 1.6366903	best: 1.6366903 (300)	total: 2m 3s	remaining: 5m 10s
# 400:	learn: 0.8696563	test: 1.5805919	best: 1.5805919 (400)	total: 2m 44s	remaining: 4m 29s
# 500:	learn: 0.7383749	test: 1.5407254	best: 1.5407254 (500)	total: 3m 25s	remaining: 3m 48s
# 600:	learn: 0.6304031	test: 1.5110047	best: 1.5110047 (600)	total: 4m 7s	remaining: 3m 8s
# 700:	learn: 0.5420131	test: 1.4873683	best: 1.4873683 (700)	total: 4m 48s	remaining: 2m 27s
# 800:	learn: 0.4729923	test: 1.4690373	best: 1.4690373 (800)	total: 5m 29s	remaining: 1m 45s
# 900:	learn: 0.4183975	test: 1.4554731	best: 1.4554731 (900)	total: 6m 10s	remaining: 1m 4s
# 1000:	learn: 0.3721740	test: 1.4451734	best: 1.4451734 (1000)	total: 6m 52s	remaining: 23.5s
# 1057:	learn: 0.3456796	test: 1.4386529	best: 1.4386529 (1057)	total: 7m 15s	remaining: 0us
# bestTest = 1.438652907
# bestIteration = 1057
# # Fold 2, bag 0: RMSE=1.43865
# 0:	learn: 3.0143435	test: 3.0197666	best: 3.0197666 (0)	total: 430ms	remaining: 7m 34s
# 100:	learn: 1.6144302	test: 1.8495330	best: 1.8495330 (100)	total: 41.6s	remaining: 6m 33s
# 200:	learn: 1.2753050	test: 1.7190972	best: 1.7190972 (200)	total: 1m 22s	remaining: 5m 51s
# 300:	learn: 1.0473527	test: 1.6366903	best: 1.6366903 (300)	total: 2m 3s	remaining: 5m 10s
# 400:	learn: 0.8696563	test: 1.5805919	best: 1.5805919 (400)	total: 2m 44s	remaining: 4m 29s
# 500:	learn: 0.7383749	test: 1.5407254	best: 1.5407254 (500)	total: 3m 25s	remaining: 3m 48s
# 600:	learn: 0.6304031	test: 1.5110047	best: 1.5110047 (600)	total: 4m 7s	remaining: 3m 8s
# 700:	learn: 0.5420131	test: 1.4873683	best: 1.4873683 (700)	total: 4m 48s	remaining: 2m 27s
# 800:	learn: 0.4729923	test: 1.4690373	best: 1.4690373 (800)	total: 5m 29s	remaining: 1m 45s
# 900:	learn: 0.4183975	test: 1.4554731	best: 1.4554731 (900)	total: 6m 10s	remaining: 1m 4s
# 1000:	learn: 0.3721740	test: 1.4451734	best: 1.4451734 (1000)	total: 6m 52s	remaining: 23.5s
# 1057:	learn: 0.3456796	test: 1.4386529	best: 1.4386529 (1057)	total: 7m 15s	remaining: 0us
# bestTest = 1.438652907
# bestIteration = 1057
# # Fold 2, bag 1: RMSE=1.43865
# 0:	learn: 3.0143435	test: 3.0197666	best: 3.0197666 (0)	total: 406ms	remaining: 7m 9s
# 100:	learn: 1.6144302	test: 1.8495330	best: 1.8495330 (100)	total: 41.5s	remaining: 6m 33s
# 200:	learn: 1.2753050	test: 1.7190972	best: 1.7190972 (200)	total: 1m 22s	remaining: 5m 51s
# 300:	learn: 1.0473527	test: 1.6366903	best: 1.6366903 (300)	total: 2m 3s	remaining: 5m 10s
# 400:	learn: 0.8696563	test: 1.5805919	best: 1.5805919 (400)	total: 2m 44s	remaining: 4m 29s
# 500:	learn: 0.7383749	test: 1.5407254	best: 1.5407254 (500)	total: 3m 25s	remaining: 3m 49s
# 600:	learn: 0.6304061	test: 1.5110050	best: 1.5110050 (600)	total: 4m 7s	remaining: 3m 8s
# 700:	learn: 0.5420159	test: 1.4873688	best: 1.4873688 (700)	total: 4m 48s	remaining: 2m 27s
# 800:	learn: 0.4729949	test: 1.4690377	best: 1.4690377 (800)	total: 5m 29s	remaining: 1m 45s
# 900:	learn: 0.4169936	test: 1.4548875	best: 1.4548875 (900)	total: 6m 11s	remaining: 1m 4s
# 1000:	learn: 0.3683978	test: 1.4437530	best: 1.4437530 (1000)	total: 6m 52s	remaining: 23.5s
# 1057:	learn: 0.3453059	test: 1.4387260	best: 1.4387260 (1057)	total: 7m 16s	remaining: 0us
# bestTest = 1.438726033
# bestIteration = 1057
# # Fold 2, bag 2: RMSE=1.43873
# #RMSE mean: 1.4397980 (+- 0.0056734)
# 0:	learn: 3.0147747	test: 3.0248584	best: 3.0248584 (0)	total: 386ms	remaining: 6m 47s
# 100:	learn: 1.6363927	test: 1.8359276	best: 1.8359276 (100)	total: 41.4s	remaining: 6m 31s
# 200:	learn: 1.2818537	test: 1.6985178	best: 1.6985178 (200)	total: 1m 22s	remaining: 5m 51s
# 300:	learn: 1.0440463	test: 1.6201478	best: 1.6201478 (300)	total: 2m 3s	remaining: 5m 11s
# 400:	learn: 0.8694290	test: 1.5642053	best: 1.5642053 (400)	total: 2m 44s	remaining: 4m 30s
# 500:	learn: 0.7352897	test: 1.5242654	best: 1.5242654 (500)	total: 3m 26s	remaining: 3m 49s
# 600:	learn: 0.6324167	test: 1.4964865	best: 1.4964865 (600)	total: 4m 7s	remaining: 3m 8s
# 700:	learn: 0.5470945	test: 1.4752707	best: 1.4752707 (700)	total: 4m 48s	remaining: 2m 27s
# 800:	learn: 0.4768057	test: 1.4580215	best: 1.4580215 (800)	total: 5m 30s	remaining: 1m 45s
# 900:	learn: 0.4192968	test: 1.4437923	best: 1.4437923 (900)	total: 6m 11s	remaining: 1m 4s
# 1000:	learn: 0.3708191	test: 1.4325359	best: 1.4325359 (1000)	total: 6m 52s	remaining: 23.5s
# 1057:	learn: 0.3455665	test: 1.4273342	best: 1.4273342 (1057)	total: 7m 16s	remaining: 0us
# bestTest = 1.427334154
# bestIteration = 1057
# # Fold 3, bag 0: RMSE=1.42733
# 0:	learn: 3.0147747	test: 3.0248584	best: 3.0248584 (0)	total: 389ms	remaining: 6m 51s
# 100:	learn: 1.6363927	test: 1.8359276	best: 1.8359276 (100)	total: 41.3s	remaining: 6m 31s
# 200:	learn: 1.2818537	test: 1.6985178	best: 1.6985178 (200)	total: 1m 22s	remaining: 5m 51s
# 300:	learn: 1.0440463	test: 1.6201478	best: 1.6201478 (300)	total: 2m 3s	remaining: 5m 10s
# 400:	learn: 0.8694290	test: 1.5642053	best: 1.5642053 (400)	total: 2m 44s	remaining: 4m 29s
# 500:	learn: 0.7352897	test: 1.5242654	best: 1.5242654 (500)	total: 3m 25s	remaining: 3m 48s
# 600:	learn: 0.6324167	test: 1.4964865	best: 1.4964865 (600)	total: 4m 7s	remaining: 3m 7s
# 700:	learn: 0.5470945	test: 1.4752707	best: 1.4752707 (700)	total: 4m 48s	remaining: 2m 26s
# 800:	learn: 0.4768057	test: 1.4580215	best: 1.4580215 (800)	total: 5m 29s	remaining: 1m 45s
# 900:	learn: 0.4192968	test: 1.4437923	best: 1.4437923 (900)	total: 6m 10s	remaining: 1m 4s
# 1000:	learn: 0.3708191	test: 1.4325359	best: 1.4325359 (1000)	total: 6m 51s	remaining: 23.4s
# 1057:	learn: 0.3455665	test: 1.4273342	best: 1.4273342 (1057)	total: 7m 15s	remaining: 0us
# bestTest = 1.427334154
# bestIteration = 1057
# # Fold 3, bag 1: RMSE=1.42733
# 0:	learn: 3.0147747	test: 3.0248584	best: 3.0248584 (0)	total: 382ms	remaining: 6m 43s
# 100:	learn: 1.6363927	test: 1.8359276	best: 1.8359276 (100)	total: 41.4s	remaining: 6m 31s
# 200:	learn: 1.2818537	test: 1.6985178	best: 1.6985178 (200)	total: 1m 22s	remaining: 5m 51s
# 300:	learn: 1.0440463	test: 1.6201477	best: 1.6201477 (300)	total: 2m 3s	remaining: 5m 11s
# 400:	learn: 0.8694293	test: 1.5642053	best: 1.5642053 (400)	total: 2m 44s	remaining: 4m 30s
# 500:	learn: 0.7352900	test: 1.5242654	best: 1.5242654 (500)	total: 3m 26s	remaining: 3m 49s
# 600:	learn: 0.6324170	test: 1.4964866	best: 1.4964866 (600)	total: 4m 7s	remaining: 3m 8s
# 700:	learn: 0.5470947	test: 1.4752706	best: 1.4752706 (700)	total: 4m 48s	remaining: 2m 27s
# 800:	learn: 0.4768058	test: 1.4580217	best: 1.4580217 (800)	total: 5m 30s	remaining: 1m 45s
# 900:	learn: 0.4192970	test: 1.4437924	best: 1.4437924 (900)	total: 6m 11s	remaining: 1m 4s
# 1000:	learn: 0.3708192	test: 1.4325361	best: 1.4325361 (1000)	total: 6m 52s	remaining: 23.5s
# 1057:	learn: 0.3455666	test: 1.4273345	best: 1.4273345 (1057)	total: 7m 15s	remaining: 0us
# bestTest = 1.427334462
# bestIteration = 1057
# # Fold 3, bag 2: RMSE=1.42733
# #RMSE mean: 1.4366821 (+- 0.0072985)
# 0:	learn: 3.0166599	test: 3.0233371	best: 3.0233371 (0)	total: 400ms	remaining: 7m 2s
# 100:	learn: 1.6141826	test: 1.8501231	best: 1.8501231 (100)	total: 41.4s	remaining: 6m 32s
# 200:	learn: 1.2863216	test: 1.7262677	best: 1.7262677 (200)	total: 1m 22s	remaining: 5m 50s
# 300:	learn: 1.0428130	test: 1.6383100	best: 1.6383100 (300)	total: 2m 3s	remaining: 5m 10s
# 400:	learn: 0.8726046	test: 1.5833310	best: 1.5833310 (400)	total: 2m 44s	remaining: 4m 29s
# 500:	learn: 0.7351704	test: 1.5430044	best: 1.5430044 (500)	total: 3m 26s	remaining: 3m 49s
# 600:	learn: 0.6290729	test: 1.5143614	best: 1.5143614 (600)	total: 4m 7s	remaining: 3m 8s
# 700:	learn: 0.5480790	test: 1.4927312	best: 1.4927312 (700)	total: 4m 48s	remaining: 2m 26s
# 800:	learn: 0.4769731	test: 1.4754880	best: 1.4754880 (800)	total: 5m 29s	remaining: 1m 45s
# 900:	learn: 0.4213580	test: 1.4627399	best: 1.4627399 (900)	total: 6m 10s	remaining: 1m 4s
# 1000:	learn: 0.3709370	test: 1.4513559	best: 1.4513559 (1000)	total: 6m 52s	remaining: 23.5s
# 1057:	learn: 0.3476352	test: 1.4461060	best: 1.4461060 (1057)	total: 7m 15s	remaining: 0us
# bestTest = 1.446105958
# bestIteration = 1057
# # Fold 4, bag 0: RMSE=1.44611
# 0:	learn: 3.0166599	test: 3.0233371	best: 3.0233371 (0)	total: 396ms	remaining: 6m 58s
# 100:	learn: 1.6141826	test: 1.8501231	best: 1.8501231 (100)	total: 41.5s	remaining: 6m 33s
# 200:	learn: 1.2863216	test: 1.7262677	best: 1.7262677 (200)	total: 1m 22s	remaining: 5m 50s
# 300:	learn: 1.0428130	test: 1.6383100	best: 1.6383100 (300)	total: 2m 3s	remaining: 5m 10s
# 400:	learn: 0.8726046	test: 1.5833310	best: 1.5833310 (400)	total: 2m 44s	remaining: 4m 29s
# 500:	learn: 0.7351704	test: 1.5430044	best: 1.5430044 (500)	total: 3m 26s	remaining: 3m 49s
# 600:	learn: 0.6290729	test: 1.5143614	best: 1.5143614 (600)	total: 4m 7s	remaining: 3m 8s
# 700:	learn: 0.5480790	test: 1.4927312	best: 1.4927312 (700)	total: 4m 48s	remaining: 2m 26s
# 800:	learn: 0.4769731	test: 1.4754880	best: 1.4754880 (800)	total: 5m 29s	remaining: 1m 45s
# 900:	learn: 0.4213580	test: 1.4627399	best: 1.4627399 (900)	total: 6m 11s	remaining: 1m 4s
# 1000:	learn: 0.3709370	test: 1.4513559	best: 1.4513559 (1000)	total: 6m 52s	remaining: 23.5s
# 1057:	learn: 0.3476352	test: 1.4461060	best: 1.4461060 (1057)	total: 7m 15s	remaining: 0us
# bestTest = 1.446105958
# bestIteration = 1057
# # Fold 4, bag 1: RMSE=1.44611
# 0:	learn: 3.0166599	test: 3.0233371	best: 3.0233371 (0)	total: 400ms	remaining: 7m 2s
# 100:	learn: 1.6141826	test: 1.8501231	best: 1.8501231 (100)	total: 41.4s	remaining: 6m 32s
# 200:	learn: 1.2863216	test: 1.7262677	best: 1.7262677 (200)	total: 1m 22s	remaining: 5m 50s
# 300:	learn: 1.0428130	test: 1.6383100	best: 1.6383100 (300)	total: 2m 3s	remaining: 5m 10s
# 400:	learn: 0.8726046	test: 1.5833310	best: 1.5833310 (400)	total: 2m 44s	remaining: 4m 29s
# 500:	learn: 0.7351704	test: 1.5430044	best: 1.5430044 (500)	total: 3m 26s	remaining: 3m 49s
# 600:	learn: 0.6290729	test: 1.5143614	best: 1.5143614 (600)	total: 4m 7s	remaining: 3m 8s
# 700:	learn: 0.5480790	test: 1.4927312	best: 1.4927312 (700)	total: 4m 48s	remaining: 2m 26s
# 800:	learn: 0.4769731	test: 1.4754880	best: 1.4754880 (800)	total: 5m 29s	remaining: 1m 45s
# 900:	learn: 0.4213580	test: 1.4627399	best: 1.4627399 (900)	total: 6m 10s	remaining: 1m 4s
# 1000:	learn: 0.3709370	test: 1.4513559	best: 1.4513559 (1000)	total: 6m 52s	remaining: 23.5s
# 1057:	learn: 0.3476352	test: 1.4461060	best: 1.4461060 (1057)	total: 7m 15s	remaining: 0us
# bestTest = 1.446105958
# bestIteration = 1057
# # Fold 4, bag 2: RMSE=1.44611
# #RMSE mean: 1.4385669 (+- 0.0075382)
# Trial 1, final RMSE: 1.4384794803844665
# Saved best test with RMSE score: 1.4384794803844665
# 0:	learn: 2.9012081	test: 2.8962560	best: 2.8962560 (0)	total: 130ms	remaining: 2m 57s
# 100:	learn: 1.7842099	test: 1.8999313	best: 1.8999313 (100)	total: 12.5s	remaining: 2m 36s
# 200:	learn: 1.5669045	test: 1.8092347	best: 1.8092347 (200)	total: 25s	remaining: 2m 24s
# 300:	learn: 1.4045937	test: 1.7537081	best: 1.7537081 (300)	total: 37.6s	remaining: 2m 12s
# 400:	learn: 1.2731224	test: 1.7049827	best: 1.7049827 (400)	total: 50.1s	remaining: 2m
# 500:	learn: 1.1569557	test: 1.6668298	best: 1.6668298 (500)	total: 1m 2s	remaining: 1m 48s
# 600:	learn: 1.0622226	test: 1.6398844	best: 1.6398844 (600)	total: 1m 15s	remaining: 1m 36s
# 700:	learn: 0.9769006	test: 1.6112690	best: 1.6112690 (700)	total: 1m 28s	remaining: 1m 23s
# 800:	learn: 0.9098677	test: 1.5926339	best: 1.5926339 (800)	total: 1m 40s	remaining: 1m 10s
# 900:	learn: 0.8424076	test: 1.5735615	best: 1.5735615 (900)	total: 1m 53s	remaining: 58.4s
# 1000:	learn: 0.7836052	test: 1.5573882	best: 1.5573882 (1000)	total: 2m 5s	remaining: 45.9s
# 1100:	learn: 0.7311591	test: 1.5435410	best: 1.5435410 (1100)	total: 2m 18s	remaining: 33.3s
# 1200:	learn: 0.6821636	test: 1.5317598	best: 1.5317598 (1200)	total: 2m 31s	remaining: 20.8s
# 1300:	learn: 0.6384334	test: 1.5200674	best: 1.5200613 (1299)	total: 2m 43s	remaining: 8.18s
# 1365:	learn: 0.6126156	test: 1.5143141	best: 1.5143141 (1365)	total: 2m 51s	remaining: 0us
# bestTest = 1.514314132
# bestIteration = 1365
# # Fold 0, bag 0: RMSE=1.51431
# 0:	learn: 2.9012081	test: 2.8962560	best: 2.8962560 (0)	total: 130ms	remaining: 2m 57s
# 100:	learn: 1.7842099	test: 1.8999313	best: 1.8999313 (100)	total: 12.5s	remaining: 2m 36s
# 200:	learn: 1.5669045	test: 1.8092347	best: 1.8092347 (200)	total: 25s	remaining: 2m 24s
# 300:	learn: 1.4045937	test: 1.7537081	best: 1.7537081 (300)	total: 37.6s	remaining: 2m 12s
# 400:	learn: 1.2731224	test: 1.7049827	best: 1.7049827 (400)	total: 50.1s	remaining: 2m
# 500:	learn: 1.1569557	test: 1.6668298	best: 1.6668298 (500)	total: 1m 2s	remaining: 1m 48s
# 600:	learn: 1.0622226	test: 1.6398844	best: 1.6398844 (600)	total: 1m 15s	remaining: 1m 35s
# 700:	learn: 0.9769006	test: 1.6112690	best: 1.6112690 (700)	total: 1m 27s	remaining: 1m 23s
# 800:	learn: 0.9098677	test: 1.5926339	best: 1.5926339 (800)	total: 1m 40s	remaining: 1m 10s
# 900:	learn: 0.8424076	test: 1.5735615	best: 1.5735615 (900)	total: 1m 53s	remaining: 58.4s
# 1000:	learn: 0.7836052	test: 1.5573882	best: 1.5573882 (1000)	total: 2m 5s	remaining: 45.8s
# 1100:	learn: 0.7311591	test: 1.5435410	best: 1.5435410 (1100)	total: 2m 18s	remaining: 33.3s
# 1200:	learn: 0.6821636	test: 1.5317598	best: 1.5317598 (1200)	total: 2m 30s	remaining: 20.7s
# 1300:	learn: 0.6384334	test: 1.5200674	best: 1.5200613 (1299)	total: 2m 43s	remaining: 8.16s
# 1365:	learn: 0.6126156	test: 1.5143141	best: 1.5143141 (1365)	total: 2m 51s	remaining: 0us
# bestTest = 1.514314132
# bestIteration = 1365
# # Fold 0, bag 1: RMSE=1.51431
# 0:	learn: 2.9012081	test: 2.8962560	best: 2.8962560 (0)	total: 129ms	remaining: 2m 56s
# 100:	learn: 1.7842099	test: 1.8999313	best: 1.8999313 (100)	total: 12.6s	remaining: 2m 37s
# 200:	learn: 1.5669045	test: 1.8092347	best: 1.8092347 (200)	total: 25.1s	remaining: 2m 25s
# 300:	learn: 1.4045937	test: 1.7537081	best: 1.7537081 (300)	total: 37.7s	remaining: 2m 13s
# 400:	learn: 1.2731224	test: 1.7049827	best: 1.7049827 (400)	total: 50.3s	remaining: 2m
# 500:	learn: 1.1569557	test: 1.6668298	best: 1.6668298 (500)	total: 1m 2s	remaining: 1m 48s
# 600:	learn: 1.0622226	test: 1.6398844	best: 1.6398844 (600)	total: 1m 15s	remaining: 1m 36s
# 700:	learn: 0.9769006	test: 1.6112690	best: 1.6112690 (700)	total: 1m 28s	remaining: 1m 23s
# 800:	learn: 0.9098677	test: 1.5926339	best: 1.5926339 (800)	total: 1m 40s	remaining: 1m 10s
# 900:	learn: 0.8424076	test: 1.5735615	best: 1.5735615 (900)	total: 1m 53s	remaining: 58.4s
# 1000:	learn: 0.7836052	test: 1.5573882	best: 1.5573882 (1000)	total: 2m 5s	remaining: 45.9s
# 1100:	learn: 0.7311591	test: 1.5435410	best: 1.5435410 (1100)	total: 2m 18s	remaining: 33.3s
# 1200:	learn: 0.6821636	test: 1.5317598	best: 1.5317598 (1200)	total: 2m 31s	remaining: 20.7s
# 1300:	learn: 0.6384334	test: 1.5200674	best: 1.5200613 (1299)	total: 2m 43s	remaining: 8.17s
# 1365:	learn: 0.6126156	test: 1.5143141	best: 1.5143141 (1365)	total: 2m 51s	remaining: 0us
# bestTest = 1.514314132
# bestIteration = 1365
# # Fold 0, bag 2: RMSE=1.51431
# #RMSE mean: 1.5143142 (+- 0.0000000)
# 0:	learn: 2.9015720	test: 2.8856405	best: 2.8856405 (0)	total: 130ms	remaining: 2m 57s
# 100:	learn: 1.7875057	test: 1.8994414	best: 1.8994414 (100)	total: 12.5s	remaining: 2m 35s
# 200:	learn: 1.5684960	test: 1.8050149	best: 1.8050149 (200)	total: 25.1s	remaining: 2m 25s
# 300:	learn: 1.3987183	test: 1.7395085	best: 1.7395085 (300)	total: 37.6s	remaining: 2m 13s
# 400:	learn: 1.2746763	test: 1.6983937	best: 1.6983937 (400)	total: 50.2s	remaining: 2m
# 500:	learn: 1.1627357	test: 1.6641225	best: 1.6641225 (500)	total: 1m 2s	remaining: 1m 48s
# 600:	learn: 1.0671220	test: 1.6332960	best: 1.6332960 (600)	total: 1m 15s	remaining: 1m 35s
# 700:	learn: 0.9830377	test: 1.6070270	best: 1.6070270 (700)	total: 1m 27s	remaining: 1m 23s
# 800:	learn: 0.9108223	test: 1.5870079	best: 1.5870079 (800)	total: 1m 40s	remaining: 1m 10s
# 900:	learn: 0.8431511	test: 1.5675759	best: 1.5675380 (899)	total: 1m 53s	remaining: 58.4s
# 1000:	learn: 0.7821988	test: 1.5501773	best: 1.5501773 (1000)	total: 2m 5s	remaining: 45.9s
# 1100:	learn: 0.7279973	test: 1.5345845	best: 1.5345845 (1100)	total: 2m 18s	remaining: 33.3s
# 1200:	learn: 0.6789979	test: 1.5213677	best: 1.5213677 (1200)	total: 2m 31s	remaining: 20.8s
# 1300:	learn: 0.6341189	test: 1.5094318	best: 1.5094318 (1300)	total: 2m 43s	remaining: 8.19s
# 1365:	learn: 0.6086117	test: 1.5025480	best: 1.5025480 (1365)	total: 2m 52s	remaining: 0us
# bestTest = 1.502547992
# bestIteration = 1365
# # Fold 1, bag 0: RMSE=1.50255
# 0:	learn: 2.9015720	test: 2.8856405	best: 2.8856405 (0)	total: 128ms	remaining: 2m 55s
# 100:	learn: 1.7875057	test: 1.8994414	best: 1.8994414 (100)	total: 12.4s	remaining: 2m 35s
# 200:	learn: 1.5684960	test: 1.8050149	best: 1.8050149 (200)	total: 25s	remaining: 2m 24s
# 300:	learn: 1.3987183	test: 1.7395085	best: 1.7395085 (300)	total: 37.6s	remaining: 2m 12s
# 400:	learn: 1.2746763	test: 1.6983937	best: 1.6983937 (400)	total: 50.1s	remaining: 2m
# 500:	learn: 1.1627357	test: 1.6641225	best: 1.6641225 (500)	total: 1m 2s	remaining: 1m 48s
# 600:	learn: 1.0671220	test: 1.6332960	best: 1.6332960 (600)	total: 1m 15s	remaining: 1m 35s
# 700:	learn: 0.9830377	test: 1.6070270	best: 1.6070270 (700)	total: 1m 27s	remaining: 1m 23s
# 800:	learn: 0.9108223	test: 1.5870079	best: 1.5870079 (800)	total: 1m 40s	remaining: 1m 10s
# 900:	learn: 0.8431511	test: 1.5675759	best: 1.5675380 (899)	total: 1m 52s	remaining: 58.3s
# 1000:	learn: 0.7821988	test: 1.5501773	best: 1.5501773 (1000)	total: 2m 5s	remaining: 45.8s
# 1100:	learn: 0.7279973	test: 1.5345845	best: 1.5345845 (1100)	total: 2m 18s	remaining: 33.3s
# 1200:	learn: 0.6789979	test: 1.5213677	best: 1.5213677 (1200)	total: 2m 30s	remaining: 20.7s
# 1300:	learn: 0.6341189	test: 1.5094318	best: 1.5094318 (1300)	total: 2m 43s	remaining: 8.17s
# 1365:	learn: 0.6086117	test: 1.5025480	best: 1.5025480 (1365)	total: 2m 51s	remaining: 0us
# bestTest = 1.502547992
# bestIteration = 1365
# # Fold 1, bag 1: RMSE=1.50255
# 0:	learn: 2.9015720	test: 2.8856405	best: 2.8856405 (0)	total: 130ms	remaining: 2m 57s
# 100:	learn: 1.7875057	test: 1.8994414	best: 1.8994414 (100)	total: 12.4s	remaining: 2m 35s
# 200:	learn: 1.5684960	test: 1.8050149	best: 1.8050149 (200)	total: 25s	remaining: 2m 24s
# 300:	learn: 1.3987183	test: 1.7395085	best: 1.7395085 (300)	total: 37.6s	remaining: 2m 13s
# 400:	learn: 1.2746763	test: 1.6983937	best: 1.6983937 (400)	total: 50.2s	remaining: 2m
# 500:	learn: 1.1627357	test: 1.6641225	best: 1.6641225 (500)	total: 1m 2s	remaining: 1m 48s
# 600:	learn: 1.0671220	test: 1.6332960	best: 1.6332960 (600)	total: 1m 15s	remaining: 1m 35s
# 700:	learn: 0.9830377	test: 1.6070270	best: 1.6070270 (700)	total: 1m 27s	remaining: 1m 23s
# 800:	learn: 0.9108223	test: 1.5870079	best: 1.5870079 (800)	total: 1m 40s	remaining: 1m 10s
# 900:	learn: 0.8431511	test: 1.5675759	best: 1.5675380 (899)	total: 1m 53s	remaining: 58.4s
# 1000:	learn: 0.7821988	test: 1.5501773	best: 1.5501773 (1000)	total: 2m 5s	remaining: 45.9s
# 1100:	learn: 0.7279973	test: 1.5345845	best: 1.5345845 (1100)	total: 2m 18s	remaining: 33.4s
# 1200:	learn: 0.6789979	test: 1.5213677	best: 1.5213677 (1200)	total: 2m 31s	remaining: 20.8s
# 1300:	learn: 0.6341189	test: 1.5094318	best: 1.5094318 (1300)	total: 2m 43s	remaining: 8.18s
# 1365:	learn: 0.6086117	test: 1.5025480	best: 1.5025480 (1365)	total: 2m 52s	remaining: 0us
# bestTest = 1.502547992
# bestIteration = 1365
# # Fold 1, bag 2: RMSE=1.50255
# #RMSE mean: 1.5084311 (+- 0.0058831)
# 0:	learn: 2.8983435	test: 2.9029940	best: 2.9029940 (0)	total: 127ms	remaining: 2m 53s
# 100:	learn: 1.7849859	test: 1.9010400	best: 1.9010400 (100)	total: 12.5s	remaining: 2m 36s
# 200:	learn: 1.5660186	test: 1.8040727	best: 1.8040727 (200)	total: 25s	remaining: 2m 24s
# 300:	learn: 1.3975468	test: 1.7346682	best: 1.7346682 (300)	total: 37.6s	remaining: 2m 13s
# 400:	learn: 1.2615646	test: 1.6907468	best: 1.6907468 (400)	total: 50.2s	remaining: 2m
# 500:	learn: 1.1558194	test: 1.6555055	best: 1.6555055 (500)	total: 1m 2s	remaining: 1m 48s
# 600:	learn: 1.0611190	test: 1.6267695	best: 1.6267695 (600)	total: 1m 15s	remaining: 1m 35s
# 700:	learn: 0.9742524	test: 1.6011172	best: 1.6011172 (700)	total: 1m 27s	remaining: 1m 23s
# 800:	learn: 0.9002892	test: 1.5801099	best: 1.5801099 (800)	total: 1m 40s	remaining: 1m 10s
# 900:	learn: 0.8366575	test: 1.5624743	best: 1.5624743 (900)	total: 1m 53s	remaining: 58.4s
# 1000:	learn: 0.7811368	test: 1.5479927	best: 1.5479927 (1000)	total: 2m 5s	remaining: 45.8s
# 1100:	learn: 0.7278697	test: 1.5333597	best: 1.5333597 (1100)	total: 2m 18s	remaining: 33.3s
# 1200:	learn: 0.6814626	test: 1.5216473	best: 1.5216473 (1200)	total: 2m 30s	remaining: 20.7s
# 1300:	learn: 0.6374490	test: 1.5105296	best: 1.5105296 (1300)	total: 2m 43s	remaining: 8.17s
# 1365:	learn: 0.6089934	test: 1.5029681	best: 1.5029681 (1365)	total: 2m 51s	remaining: 0us
# bestTest = 1.502968114
# bestIteration = 1365
# # Fold 2, bag 0: RMSE=1.50297
# 0:	learn: 2.8983435	test: 2.9029940	best: 2.9029940 (0)	total: 123ms	remaining: 2m 47s
# 100:	learn: 1.7849859	test: 1.9010400	best: 1.9010400 (100)	total: 12.5s	remaining: 2m 36s
# 200:	learn: 1.5660186	test: 1.8040727	best: 1.8040727 (200)	total: 25s	remaining: 2m 24s
# 300:	learn: 1.3975468	test: 1.7346682	best: 1.7346682 (300)	total: 37.6s	remaining: 2m 12s
# 400:	learn: 1.2615646	test: 1.6907468	best: 1.6907468 (400)	total: 50.1s	remaining: 2m
# 500:	learn: 1.1558194	test: 1.6555055	best: 1.6555055 (500)	total: 1m 2s	remaining: 1m 48s
# 600:	learn: 1.0611190	test: 1.6267695	best: 1.6267695 (600)	total: 1m 15s	remaining: 1m 35s
# 700:	learn: 0.9742524	test: 1.6011172	best: 1.6011172 (700)	total: 1m 27s	remaining: 1m 23s
# 800:	learn: 0.9002892	test: 1.5801099	best: 1.5801099 (800)	total: 1m 40s	remaining: 1m 10s
# 900:	learn: 0.8366575	test: 1.5624743	best: 1.5624743 (900)	total: 1m 53s	remaining: 58.4s
# 1000:	learn: 0.7811368	test: 1.5479927	best: 1.5479927 (1000)	total: 2m 5s	remaining: 45.9s
# 1100:	learn: 0.7278697	test: 1.5333597	best: 1.5333597 (1100)	total: 2m 18s	remaining: 33.3s
# 1200:	learn: 0.6814626	test: 1.5216473	best: 1.5216473 (1200)	total: 2m 30s	remaining: 20.7s
# 1300:	learn: 0.6374490	test: 1.5105296	best: 1.5105296 (1300)	total: 2m 43s	remaining: 8.18s
# 1365:	learn: 0.6089934	test: 1.5029681	best: 1.5029681 (1365)	total: 2m 51s	remaining: 0us
# bestTest = 1.502968114
# bestIteration = 1365
# # Fold 2, bag 1: RMSE=1.50297
# 0:	learn: 2.8983435	test: 2.9029940	best: 2.9029940 (0)	total: 127ms	remaining: 2m 53s
# 100:	learn: 1.7849859	test: 1.9010400	best: 1.9010400 (100)	total: 12.5s	remaining: 2m 36s
# 200:	learn: 1.5660186	test: 1.8040727	best: 1.8040727 (200)	total: 25s	remaining: 2m 24s
# 300:	learn: 1.3988695	test: 1.7368391	best: 1.7368391 (300)	total: 37.5s	remaining: 2m 12s
# 400:	learn: 1.2618156	test: 1.6900768	best: 1.6900768 (400)	total: 50s	remaining: 2m
# 500:	learn: 1.1551146	test: 1.6535188	best: 1.6535188 (500)	total: 1m 2s	remaining: 1m 48s
# 600:	learn: 1.0562570	test: 1.6212128	best: 1.6212128 (600)	total: 1m 15s	remaining: 1m 35s
# 700:	learn: 0.9766708	test: 1.5966096	best: 1.5966096 (700)	total: 1m 27s	remaining: 1m 23s
# 800:	learn: 0.9048353	test: 1.5748404	best: 1.5748404 (800)	total: 1m 40s	remaining: 1m 10s
# 900:	learn: 0.8416536	test: 1.5582521	best: 1.5582521 (900)	total: 1m 52s	remaining: 58.2s
# 1000:	learn: 0.7794633	test: 1.5404325	best: 1.5404325 (1000)	total: 2m 5s	remaining: 45.7s
# 1100:	learn: 0.7256481	test: 1.5265929	best: 1.5265929 (1100)	total: 2m 18s	remaining: 33.2s
# 1200:	learn: 0.6777465	test: 1.5139174	best: 1.5139174 (1200)	total: 2m 30s	remaining: 20.7s
# 1300:	learn: 0.6333896	test: 1.5015790	best: 1.5015790 (1300)	total: 2m 43s	remaining: 8.16s
# 1365:	learn: 0.6073271	test: 1.4950805	best: 1.4950805 (1365)	total: 2m 51s	remaining: 0us
# bestTest = 1.495080529
# bestIteration = 1365
# # Fold 2, bag 2: RMSE=1.49508
# #RMSE mean: 1.5057337 (+- 0.0064988)
# 0:	learn: 2.8978331	test: 2.9059609	best: 2.9059609 (0)	total: 127ms	remaining: 2m 53s
# 100:	learn: 1.7892725	test: 1.8886138	best: 1.8886138 (100)	total: 12.5s	remaining: 2m 36s
# 200:	learn: 1.5711250	test: 1.7959192	best: 1.7959192 (200)	total: 25.2s	remaining: 2m 25s
# 300:	learn: 1.4037752	test: 1.7343946	best: 1.7343946 (300)	total: 37.7s	remaining: 2m 13s
# 400:	learn: 1.2684732	test: 1.6897240	best: 1.6897240 (400)	total: 50.3s	remaining: 2m 1s
# 500:	learn: 1.1631509	test: 1.6550188	best: 1.6550188 (500)	total: 1m 2s	remaining: 1m 48s
# 600:	learn: 1.0660042	test: 1.6279635	best: 1.6279635 (600)	total: 1m 15s	remaining: 1m 36s
# 700:	learn: 0.9814481	test: 1.6023738	best: 1.6023738 (700)	total: 1m 28s	remaining: 1m 23s
# 800:	learn: 0.9053530	test: 1.5793938	best: 1.5793938 (800)	total: 1m 40s	remaining: 1m 11s
# 900:	learn: 0.8390020	test: 1.5609859	best: 1.5609859 (900)	total: 1m 53s	remaining: 58.5s
# 1000:	learn: 0.7750433	test: 1.5448720	best: 1.5448720 (1000)	total: 2m 6s	remaining: 46s
# 1100:	learn: 0.7211083	test: 1.5292172	best: 1.5292139 (1099)	total: 2m 18s	remaining: 33.4s
# 1200:	learn: 0.6753568	test: 1.5181147	best: 1.5181147 (1200)	total: 2m 31s	remaining: 20.8s
# 1300:	learn: 0.6312937	test: 1.5057126	best: 1.5057126 (1300)	total: 2m 44s	remaining: 8.19s
# 1365:	learn: 0.6071550	test: 1.4993980	best: 1.4993980 (1365)	total: 2m 52s	remaining: 0us
# bestTest = 1.499398048
# bestIteration = 1365
# # Fold 3, bag 0: RMSE=1.49940
# 0:	learn: 2.8978331	test: 2.9059609	best: 2.9059609 (0)	total: 127ms	remaining: 2m 52s
# 100:	learn: 1.7892725	test: 1.8886138	best: 1.8886138 (100)	total: 12.5s	remaining: 2m 36s
# 200:	learn: 1.5711250	test: 1.7959192	best: 1.7959192 (200)	total: 25.1s	remaining: 2m 25s
# 300:	learn: 1.4037752	test: 1.7343946	best: 1.7343946 (300)	total: 37.7s	remaining: 2m 13s
# 400:	learn: 1.2684732	test: 1.6897240	best: 1.6897240 (400)	total: 50.2s	remaining: 2m
# 500:	learn: 1.1631509	test: 1.6550188	best: 1.6550188 (500)	total: 1m 2s	remaining: 1m 48s
# 600:	learn: 1.0660042	test: 1.6279635	best: 1.6279635 (600)	total: 1m 15s	remaining: 1m 36s
# 700:	learn: 0.9814481	test: 1.6023738	best: 1.6023738 (700)	total: 1m 28s	remaining: 1m 23s
# 800:	learn: 0.9053530	test: 1.5793938	best: 1.5793938 (800)	total: 1m 40s	remaining: 1m 10s
# 900:	learn: 0.8390020	test: 1.5609859	best: 1.5609859 (900)	total: 1m 53s	remaining: 58.4s
# 1000:	learn: 0.7750433	test: 1.5448720	best: 1.5448720 (1000)	total: 2m 5s	remaining: 45.9s
# 1100:	learn: 0.7211083	test: 1.5292172	best: 1.5292139 (1099)	total: 2m 18s	remaining: 33.4s
# 1200:	learn: 0.6753568	test: 1.5181147	best: 1.5181147 (1200)	total: 2m 31s	remaining: 20.8s
# 1300:	learn: 0.6312937	test: 1.5057126	best: 1.5057126 (1300)	total: 2m 43s	remaining: 8.19s
# 1365:	learn: 0.6071550	test: 1.4993980	best: 1.4993980 (1365)	total: 2m 52s	remaining: 0us
# bestTest = 1.499398048
# bestIteration = 1365
# # Fold 3, bag 1: RMSE=1.49940
# 0:	learn: 2.8978331	test: 2.9059609	best: 2.9059609 (0)	total: 127ms	remaining: 2m 53s
# 100:	learn: 1.7892725	test: 1.8886138	best: 1.8886138 (100)	total: 12.5s	remaining: 2m 36s
# 200:	learn: 1.5711250	test: 1.7959192	best: 1.7959192 (200)	total: 25s	remaining: 2m 24s
# 300:	learn: 1.4037752	test: 1.7343946	best: 1.7343946 (300)	total: 37.6s	remaining: 2m 12s
# 400:	learn: 1.2684732	test: 1.6897240	best: 1.6897240 (400)	total: 50.2s	remaining: 2m
# 500:	learn: 1.1631509	test: 1.6550188	best: 1.6550188 (500)	total: 1m 2s	remaining: 1m 48s
# 600:	learn: 1.0660042	test: 1.6279635	best: 1.6279635 (600)	total: 1m 15s	remaining: 1m 35s
# 700:	learn: 0.9814481	test: 1.6023738	best: 1.6023738 (700)	total: 1m 27s	remaining: 1m 23s
# 800:	learn: 0.9053530	test: 1.5793938	best: 1.5793938 (800)	total: 1m 40s	remaining: 1m 10s
# 900:	learn: 0.8390020	test: 1.5609859	best: 1.5609859 (900)	total: 1m 53s	remaining: 58.4s
# 1000:	learn: 0.7750433	test: 1.5448720	best: 1.5448720 (1000)	total: 2m 5s	remaining: 45.9s
# 1100:	learn: 0.7211083	test: 1.5292172	best: 1.5292139 (1099)	total: 2m 18s	remaining: 33.3s
# 1200:	learn: 0.6753568	test: 1.5181147	best: 1.5181147 (1200)	total: 2m 31s	remaining: 20.8s
# 1300:	learn: 0.6312937	test: 1.5057126	best: 1.5057126 (1300)	total: 2m 43s	remaining: 8.18s
# 1365:	learn: 0.6071550	test: 1.4993980	best: 1.4993980 (1365)	total: 2m 51s	remaining: 0us
# bestTest = 1.499398048
# bestIteration = 1365
# # Fold 3, bag 2: RMSE=1.49940
# #RMSE mean: 1.5041498 (+- 0.0062611)
# 0:	learn: 2.9004531	test: 2.9077102	best: 2.9077102 (0)	total: 118ms	remaining: 2m 40s
# 100:	learn: 1.7843085	test: 1.9071424	best: 1.9071424 (100)	total: 12.5s	remaining: 2m 36s
# 200:	learn: 1.5681747	test: 1.8090252	best: 1.8090252 (200)	total: 25.1s	remaining: 2m 25s
# 300:	learn: 1.4081264	test: 1.7492465	best: 1.7492465 (300)	total: 37.6s	remaining: 2m 13s
# 400:	learn: 1.2759546	test: 1.7031354	best: 1.7031354 (400)	total: 50.2s	remaining: 2m
# 500:	learn: 1.1652569	test: 1.6691898	best: 1.6691898 (500)	total: 1m 2s	remaining: 1m 48s
# 600:	learn: 1.0696241	test: 1.6380420	best: 1.6380420 (600)	total: 1m 15s	remaining: 1m 35s
# 700:	learn: 0.9860244	test: 1.6130886	best: 1.6130886 (700)	total: 1m 27s	remaining: 1m 23s
# 800:	learn: 0.9098495	test: 1.5880753	best: 1.5880753 (800)	total: 1m 40s	remaining: 1m 10s
# 900:	learn: 0.8414267	test: 1.5691279	best: 1.5691279 (900)	total: 1m 53s	remaining: 58.5s
# 1000:	learn: 0.7797717	test: 1.5515409	best: 1.5515409 (1000)	total: 2m 6s	remaining: 46s
# 1100:	learn: 0.7287879	test: 1.5383838	best: 1.5383838 (1100)	total: 2m 18s	remaining: 33.4s
# 1200:	learn: 0.6793421	test: 1.5249535	best: 1.5249535 (1200)	total: 2m 31s	remaining: 20.8s
# 1300:	learn: 0.6334373	test: 1.5132815	best: 1.5132815 (1300)	total: 2m 43s	remaining: 8.19s
# 1365:	learn: 0.6088877	test: 1.5074028	best: 1.5074028 (1365)	total: 2m 52s	remaining: 0us
# bestTest = 1.507402849
# bestIteration = 1365
# # Fold 4, bag 0: RMSE=1.50740
# 0:	learn: 2.9004531	test: 2.9077102	best: 2.9077102 (0)	total: 121ms	remaining: 2m 44s
# 100:	learn: 1.7843085	test: 1.9071424	best: 1.9071424 (100)	total: 12.6s	remaining: 2m 37s
# 200:	learn: 1.5681747	test: 1.8090252	best: 1.8090252 (200)	total: 25.1s	remaining: 2m 25s
# 300:	learn: 1.4081264	test: 1.7492465	best: 1.7492465 (300)	total: 37.6s	remaining: 2m 13s
# 400:	learn: 1.2759546	test: 1.7031354	best: 1.7031354 (400)	total: 50.2s	remaining: 2m
# 500:	learn: 1.1652569	test: 1.6691898	best: 1.6691898 (500)	total: 1m 2s	remaining: 1m 48s
# 600:	learn: 1.0696241	test: 1.6380420	best: 1.6380420 (600)	total: 1m 15s	remaining: 1m 35s
# 700:	learn: 0.9860244	test: 1.6130886	best: 1.6130886 (700)	total: 1m 27s	remaining: 1m 23s
# 800:	learn: 0.9091364	test: 1.5905823	best: 1.5905823 (800)	total: 1m 40s	remaining: 1m 11s
# 900:	learn: 0.8418256	test: 1.5713539	best: 1.5713539 (900)	total: 1m 53s	remaining: 58.5s
# 1000:	learn: 0.7812233	test: 1.5543878	best: 1.5543878 (1000)	total: 2m 5s	remaining: 45.9s
# 1100:	learn: 0.7290527	test: 1.5398453	best: 1.5398453 (1100)	total: 2m 18s	remaining: 33.4s
# 1200:	learn: 0.6805978	test: 1.5266532	best: 1.5266532 (1200)	total: 2m 31s	remaining: 20.8s
# 1300:	learn: 0.6369638	test: 1.5150148	best: 1.5150148 (1300)	total: 2m 43s	remaining: 8.18s
# 1365:	learn: 0.6121602	test: 1.5094685	best: 1.5094685 (1365)	total: 2m 51s	remaining: 0us
# bestTest = 1.509468495
# bestIteration = 1365
# # Fold 4, bag 1: RMSE=1.50947
# 0:	learn: 2.9004531	test: 2.9077102	best: 2.9077102 (0)	total: 122ms	remaining: 2m 46s
# 100:	learn: 1.7843085	test: 1.9071424	best: 1.9071424 (100)	total: 12.5s	remaining: 2m 36s
# 200:	learn: 1.5681747	test: 1.8090252	best: 1.8090252 (200)	total: 25.1s	remaining: 2m 25s
# 300:	learn: 1.4081264	test: 1.7492465	best: 1.7492465 (300)	total: 37.6s	remaining: 2m 13s
# 400:	learn: 1.2759546	test: 1.7031354	best: 1.7031354 (400)	total: 50.2s	remaining: 2m
# 500:	learn: 1.1652569	test: 1.6691898	best: 1.6691898 (500)	total: 1m 2s	remaining: 1m 48s
# 600:	learn: 1.0696241	test: 1.6380420	best: 1.6380420 (600)	total: 1m 15s	remaining: 1m 36s
# 700:	learn: 0.9860244	test: 1.6130886	best: 1.6130886 (700)	total: 1m 28s	remaining: 1m 23s
# 800:	learn: 0.9091364	test: 1.5905823	best: 1.5905823 (800)	total: 1m 40s	remaining: 1m 11s
# 900:	learn: 0.8418256	test: 1.5713539	best: 1.5713539 (900)	total: 1m 53s	remaining: 58.5s
# 1000:	learn: 0.7812233	test: 1.5543878	best: 1.5543878 (1000)	total: 2m 6s	remaining: 46s
# 1100:	learn: 0.7290527	test: 1.5398453	best: 1.5398453 (1100)	total: 2m 18s	remaining: 33.4s
# 1200:	learn: 0.6805978	test: 1.5266532	best: 1.5266532 (1200)	total: 2m 31s	remaining: 20.8s
# 1300:	learn: 0.6369638	test: 1.5150148	best: 1.5150148 (1300)	total: 2m 43s	remaining: 8.19s
# 1365:	learn: 0.6121602	test: 1.5094685	best: 1.5094685 (1365)	total: 2m 52s	remaining: 0us
# bestTest = 1.509468495
# bestIteration = 1365
# # Fold 4, bag 2: RMSE=1.50947
# #RMSE mean: 1.5050758 (+- 0.0059145)
# Trial 2, final RMSE: 1.4992169894485012
# Best parameters: {'iterations': 1058, 'learning_rate': 0.1595789860389831, 'depth': 14}

# %%
sample_sub = pd.read_csv("/kaggle/input/brist1d/sample_submission.csv")
sample_sub['bg+1:00'] = cat_test.astype(np.float16)
sample_sub['id'] = test_id
sample_sub.drop(1)
sample_sub.to_csv('submission_cat.csv', index=False)
print(sample_sub.head())
# Out:
#          id    bg+1:00
# 0  p01_8459   8.117188
# 1  p01_8460   7.953125
# 2  p01_8461   8.289062
# 3  p01_8462  12.226562
# 4  p01_8463   8.062500

# %%
def blend_predictions(weights, oof_preds):
    """
    Blends predictions using the provided weights.
    
    Parameters:
    - weights (list or np.array): Weights for each model's predictions.
    - oof_preds (list of np.arrays): List of OOF predictions from different models.
    
    Returns:
    - np.array: Blended predictions.
    """
    blended_pred = np.zeros_like(oof_preds[0])
    for weight, oof in zip(weights, oof_preds):
        blended_pred += weight * oof
    return blended_pred


def evaluate_blend(weights, oof_preds, y_true):
    """
    Evaluates the blended predictions using a specified metric.
    
    Parameters:
    - weights (list or np.array): Weights for each model's predictions.
    - oof_preds (list of np.arrays): List of OOF predictions from different models.
    - y_true (np.array): True labels for the validation set.
    
    Returns:
    - float: RMSE score of the blended predictions.
    """
    blended_pred = blend_predictions(weights, oof_preds)
    score = np.sqrt(mean_squared_error(y_true, blended_pred))
    return score

def hill_climb_blend(oof_preds, y_true, initial_weights=None, step_size=0.05, max_iterations=100):
    """
    Performs hill climbing to find optimal weights for blending model predictions.
    
    Parameters:
    - oof_preds (list of np.arrays): List of OOF predictions from different models.
    - y_true (np.array): True labels for the validation set.
    - initial_weights (list or np.array, optional): Initial weights for each model.
    - step_size (float): Size of weight adjustments.
    - max_iterations (int): Maximum number of iterations for hill climbing.
    
    Returns:
    - np.array: Optimal weights for blending.
    - float: Best RMSE score achieved.
    """
    n_models = len(oof_preds)
    
    # Initialize weights
    if initial_weights is None:
        weights = np.array([1.0 / n_models] * n_models)  # Equal weights initially
    else:
        weights = np.array(initial_weights)
    
    # Normalize weights to sum to 1
    weights = weights / weights.sum()
    
    best_score = evaluate_blend(weights, oof_preds, y_true)
    best_weights = weights.copy()
    
    print(f"Initial weights: {best_weights}, Initial RMSE: {best_score:.5f}")
    
    for iteration in range(max_iterations):
        improved = False
        
        # Try increasing and decreasing each weight by `step_size`
        for i in range(n_models):
            for adjustment in [-step_size, step_size]:
                new_weights = best_weights.copy()
                new_weights[i] += adjustment
                
                # Normalize weights to sum to 1
                new_weights = np.maximum(new_weights, 0)  # Ensure no negative weights
                new_weights /= new_weights.sum()
                
                # Evaluate new weights
                new_score = evaluate_blend(new_weights, oof_preds, y_true)
                
                # If the new score is better, update best weights and score
                if new_score < best_score:
                    best_score = new_score
                    best_weights = new_weights
                    improved = True
                    print(f"Iteration {iteration}, Improved weights: {best_weights}, RMSE: {best_score:.5f}")
        
        # Stop if no improvement is made
        if not improved:
            break
    
    print(f"Optimal weights: {best_weights}, Best RMSE: {best_score:.5f}")
    return best_weights, best_score

# Example OOF predictions from each model (as numpy arrays)

oof_preds = [xgb_oof, lgb_oof, cat_oof]

# True labels for the validation set
y_true = y 

# Find the optimal weights
optimal_weights, best_score = hill_climb_blend(oof_preds, y_true, step_size=0.01, max_iterations=100)

print(f"Final optimal weights: {optimal_weights}, Best RMSE achieved: {best_score:.5f}")
# Out:
# Initial weights: [0.33333333 0.33333333 0.33333333], Initial RMSE: 1.35659
# Iteration 0, Improved weights: [0.32659933 0.33670034 0.33670034], RMSE: 1.35638
# Iteration 0, Improved weights: [0.32336567 0.34326766 0.33336667], RMSE: 1.35609
# Iteration 0, Improved weights: [0.32663199 0.34673501 0.326633  ], RMSE: 1.35598
# Iteration 1, Improved weights: [0.31983029 0.35023738 0.32993232], RMSE: 1.35578
# Iteration 1, Improved weights: [0.31666366 0.35667068 0.32666567], RMSE: 1.35552
# Iteration 1, Improved weights: [0.31986228 0.36027341 0.31986431], RMSE: 1.35543
# Iteration 2, Improved weights: [0.3129922  0.36391254 0.32309526], RMSE: 1.35524
# Iteration 2, Improved weights: [0.30989327 0.37021043 0.3198963 ], RMSE: 1.35500
# Iteration 2, Improved weights: [0.3130235  0.37394993 0.31302656], RMSE: 1.35491
# Iteration 3, Improved weights: [0.30608435 0.3777272  0.31618845], RMSE: 1.35473
# Iteration 3, Improved weights: [0.30305381 0.38388832 0.31305787], RMSE: 1.35453
# Iteration 3, Improved weights: [0.30611496 0.38776598 0.30611906], RMSE: 1.35445
# Iteration 4, Improved weights: [0.29910602 0.39168281 0.30921117], RMSE: 1.35428
# Iteration 4, Improved weights: [0.29614457 0.39770575 0.30614968], RMSE: 1.35410
# Iteration 4, Improved weights: [0.29913593 0.40172298 0.29914109], RMSE: 1.35403
# Iteration 5, Improved weights: [0.2920565  0.40578079 0.30216271], RMSE: 1.35388
# Iteration 5, Improved weights: [0.28916485 0.41166415 0.299171  ], RMSE: 1.35373
# Iteration 5, Improved weights: [0.29208571 0.41582237 0.29209192], RMSE: 1.35367
# Iteration 6, Improved weights: [0.28493506 0.4200226  0.29504235], RMSE: 1.35353
# Iteration 6, Improved weights: [0.28211392 0.42576495 0.29212114], RMSE: 1.35340
# Iteration 6, Improved weights: [0.28496355 0.4300656  0.28497084], RMSE: 1.35336
# Iteration 7, Improved weights: [0.27774096 0.4344097  0.28784934], RMSE: 1.35323
# Iteration 7, Improved weights: [0.27499105 0.4400096  0.28499934], RMSE: 1.35313
# Iteration 7, Improved weights: [0.27776874 0.44445415 0.27777712], RMSE: 1.35310
# Iteration 8, Improved weights: [0.27047347 0.44894358 0.28058294], RMSE: 1.35299
# Iteration 8, Improved weights: [0.26779552 0.45439959 0.2778049 ], RMSE: 1.35291
# Iteration 8, Improved weights: [0.27050052 0.45898948 0.27051   ], RMSE: 1.35290
# Iteration 9, Improved weights: [0.26313184 0.46362574 0.27324242], RMSE: 1.35280
# Iteration 9, Improved weights: [0.26052658 0.46893637 0.27053705], RMSE: 1.35275
# Iteration 10, Improved weights: [0.25305715 0.47367311 0.27326975], RMSE: 1.35268
# Iteration 10, Improved weights: [0.25055163 0.47888426 0.27056411], RMSE: 1.35265
# Iteration 11, Improved weights: [0.24298145 0.48372148 0.27329708], RMSE: 1.35260
# Iteration 11, Improved weights: [0.24057569 0.48883315 0.27059116], RMSE: 1.35258
# Iteration 12, Improved weights: [0.23290474 0.49377085 0.27332441], RMSE: 1.35256
# Iteration 12, Improved weights: [0.23059875 0.49878302 0.27061823], RMSE: 1.35256
# Optimal weights: [0.23059875 0.49878302 0.27061823], Best RMSE: 1.35256
# Final optimal weights: [0.23059875 0.49878302 0.27061823], Best RMSE achieved: 1.35256

# %%
ensemble_test = xgb_test *optimal_weights[0] + optimal_weights[1] *lgb_test + optimal_weights[2]*cat_test

# %%
sample_sub = pd.read_csv("/kaggle/input/brist1d/sample_submission.csv")
sample_sub['bg+1:00'] = ensemble_test.astype(np.float16)
sample_sub['id'] = test_id
sample_sub.drop(1)
sample_sub.to_csv('submission_ensemble.csv', index=False)
print(sample_sub.head())
# Out:
#          id    bg+1:00
# 0  p01_8459   8.273438
# 1  p01_8460   8.234375
# 2  p01_8461   8.328125
# 3  p01_8462  11.960938
# 4  p01_8463   7.886719
